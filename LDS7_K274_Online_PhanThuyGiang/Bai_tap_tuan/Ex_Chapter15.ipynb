# %%
# Tạo trang R trên colab: https://colab.research.google.com/notebook#create=true&language=r
a = 5
b = 7
c = a + b

# %%
fruit = c("a",'b','c')

# %%
print(fruit)
# Out:
# [1] "a" "b" "c"

# %%
print(c)
# Out:
# [1] 12

# %% [markdown]
# **Exercise 1: Buying T-shirt - Binominal Distribution**

# %%
# What is the probability of 2 of them buing a t-shirt? P(X = 2)
p1 <- dbinom(2, size = 8, prob = 0.3)
print(p1)
# What is the probability of 7 of them buing a t-shirt? P(X = 7)
p2 <- dbinom(7, size = 8, prob = 0.3)
print(p2)
# What is the probability that at least 2 of the customers buy a t-shirt? P(X =>
p3 <- pbinom(1, size = 8, prob = 0.3, lower.tail = FALSE)
print(p3)
# Out:
# [1] 0.2964755
# [1] 0.00122472
# [1] 0.7447017

# %% [markdown]
# **Exercise 2: Chiều cao - Normal Distribution**

# %%
height <- seq(140, 180, 0.5)
print("Samples: ")
print(height)
value <- dnorm(height, 156, 4.6)

plot(height, value,
type="l",
ylab="f(height)",
xlab="Height",
main="Probability distribution of height in Vietnamese women")
# Out:
# [1] "Samples: "
#  [1] 140.0 140.5 141.0 141.5 142.0 142.5 143.0 143.5 144.0 144.5 145.0 145.5
# [13] 146.0 146.5 147.0 147.5 148.0 148.5 149.0 149.5 150.0 150.5 151.0 151.5
# [25] 152.0 152.5 153.0 153.5 154.0 154.5 155.0 155.5 156.0 156.5 157.0 157.5
# [37] 158.0 158.5 159.0 159.5 160.0 160.5 161.0 161.5 162.0 162.5 163.0 163.5
# [49] 164.0 164.5 165.0 165.5 166.0 166.5 167.0 167.5 168.0 168.5 169.0 169.5
# [61] 170.0 170.5 171.0 171.5 172.0 172.5 173.0 173.5 174.0 174.5 175.0 175.5
# [73] 176.0 176.5 177.0 177.5 178.0 178.5 179.0 179.5 180.0
# Plot with title “Probability distribution of height in Vietnamese women”

# %%
# => nu cao 1.6m thi xac suat se la
print("Probability of height = 160 cm")
print(dnorm(160, mean=156, sd = 4.6))
# Out:
# [1] "Probability of height = 160 cm"
# [1] 0.05942343

# %% [markdown]
# **Exercise 3: Tạo mẫu theo mean và sd - Normal Distribution**

# %%
normal_sample <- rnorm(500, mean = 35, sd = 0.1)
print("10 of 500 samples:")
print(normal_sample[1:10])

hist(normal_sample, breaks = 50)
# Out:
# [1] "10 of 500 samples:"
#  [1] 35.11559 34.95731 35.03477 34.96164 35.06112 34.96525 35.01846 35.08148
#  [9] 35.04124 35.12132
# Plot with title “Histogram of normal_sample”

# %%
mean_ns <- mean(normal_sample)
print(paste("Mean:", mean_ns))
sd_ns <- sd(normal_sample)
print(paste("Sd:", sd_ns))
# Out:
# [1] "Mean: 34.9907463457106"
# [1] "Sd: 0.102780714987484"

# %% [markdown]
# **Exercise 4: Binorminal Distribution**

# %%
#Vấn đề 1: Trắc nghiệm

# English Multiple Choices
p1 <- dbinom(4, size=12, prob=0.2)
print("Probability of having four correct answers:")
print(p1)
# Out:
# [1] "Probability of having four correct answers:"
# [1] 0.1328756

# %%
# probability of having four or less correct answers
p2 <- pbinom(4, size=12, prob=0.2)
print("Probability of having four or less correct answers:")
print(p2)
# Out:
# [1] "Probability of having four or less correct answers:"
# [1] 0.9274445

# %%
#Vấn đề 2: Dùng thuốc
# symptomatic relief
p3 <- dbinom(7, size=10, prob=0.8) # having 80%
print("probability that this medication is effective:")
print(p3)
# Out:
# [1] "probability that this medication is effective:"
# [1] 0.2013266

# %%
#Vấn đề 3: Bệnh đau tim
# probability that all survive
p4 <- dbinom(0, size = 5, prob=0.04) # 0 person dies
print("probability that all survive:")
print(p4)
# Out:
# [1] "probability that all survive:"
# [1] 0.8153727

# %% [markdown]
# **Exercise 5: Thi cuối kỳ - Normal DistributionExercise 5: Thi cuối kỳ - Normal Distribution**

# %%
p1 <- pnorm(84, mean=72, sd=15.2, lower.tail=FALSE)
print("percentage of students scoring 84 or more:")
print(p1)
# Out:
# [1] "percentage of students scoring 84 or more:"
# [1] 0.2149176

# %%
y <- rnorm(100, mean = 72, sd = 15.2)
print("Samples:")
print(y)
# Out:
# [1] "Samples:"
#   [1]  72.65564 111.25154  60.33373  55.05955  77.66165  90.04774  78.80920
#   [8]  58.69254  77.96704  66.29716 107.97967 100.65766  91.51683  66.21254
#  [15]  93.99152  64.95093  59.55355  52.80559  78.38623  75.59236 107.41250
#  [22]  84.39290  41.83728  59.87384  75.97282  55.80232  96.04849  93.07026
#  [29]  78.71949  84.74981  70.62892  60.06479 107.46448  60.18071  61.41073
#  [36]  59.10780  80.72017  78.04430  50.85117  70.39198  99.04751  70.95429
#  [43]  89.24835  67.44756  59.77423  80.78480  50.91688  58.14622  43.41687
#  [50]  98.07231  82.28223  84.89544  69.10265  86.11050  74.23094  70.22865
#  [57]  66.56764  72.37266  75.44379  99.27781  72.38269  87.16954  85.49102
#  [64]  59.59202  75.05488  55.63360  77.32683  75.86280  77.45284  82.50744
#  [71]  81.76145  65.06348  72.67704  66.63133 108.44863  84.17564  64.67306
#  [78]  72.89393 101.08982  45.92585  64.52858  64.98827  49.98005  67.46537
#  [85]  70.96315  77.35624  72.90680  90.34747  83.60859  63.80608  90.90817
#  [92]  77.67717  69.28516  49.16732  84.00434  82.85140  63.82478  72.80666
#  [99]  87.92937  85.77428

# %%
hist(y, main = "Students' Scores" )
# Out:
# Plot with title “Students' Scores”
