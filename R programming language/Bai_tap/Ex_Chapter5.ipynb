# %%
# Tạo trang R trên colab: https://colab.research.google.com/notebook#create=true&language=r
a = 5
b = 7
c = a + b

# %%
fruit = c("a",'b','c')

# %%
print(fruit)
# Out:
# [1] "a" "b" "c"

# %%
print(c)
# Out:
# [1] 12

# %% [markdown]
# **Exercise 1: Tính BMI và đánh giá**

# %%
bmi.function <- function(height, weight){
  bmi <- weight/(height * height)
  return(bmi)
}

# %%
danh_gia_bmi.function <- function(bmi){
  result <-""
  if(bmi < 18.5){
    result <- "Gay"
  }else if(bmi<25){
    result <- "Binh thuong"
  }else{
    result <- "Thua can"
  }
  return(result)
}

# %%
#https://drive.google.com/file/d/1YBPxp-sI1T4DKiLY6d_OHltVvPqsk3OR/view?usp=sharing

# %%
system("gdown --id 1YBPxp-sI1T4DKiLY6d_OHltVvPqsk3OR")
source("function.R") #jupiter_notebook

# %%
height <- as.numeric(readline(prompt = "Input height (m): "))
weight <- as.numeric(readline(prompt = "Input weight (kg): "))
bmi <- bmi.function(height, weight)
danh_gia <-danh_gia_bmi.function(bmi)
# Out:
# Input height (m): 1.46
# Input weight (kg): 56

# %%
print(paste("BMI: ",bmi))
print(paste("Ket qua: ",danh_gia))
# Out:
# [1] "BMI:  26.2713454681929"
# [1] "Ket qua:  Thua can"

# %% [markdown]
# **Exercise 2: Giải PT bậc 1, PT bậc 2**

# %%
ptb1.function <- function(a,b){
result <- ""
if(a==0 & b!=0){
result <- "PT vo nghiem"
}else if(a==0 & b==0){
result <- "PT vo so nghiem"
}else{
result <- paste("Nghiem:", -b/a)
}
return(result)
}

# %%
a <- as.numeric(readline(prompt = "Input a: "))
b <- as.numeric(readline(prompt = "Input b: "))
result = ptb1.function(a,b)
print(paste(a,"x +",b,"= 0 => ",result))
# Out:
# Input a: 45
# Input b: 23
# [1] "45 x + 23 = 0 =>  Nghiem: -0.511111111111111"

# %%
# giai PT bac 2
ptb2.function <- function(a,b,c){
result <- ""
# khi a == 0 => giai PTB1
if(a==0){
result <- ptb1.function(b,c)
}else{
# giai PTB2
delta <- b*b - 4*a*c
if(delta<0){
result <- "Phuong trinh vo nghiem"
} else if(delta==0){
nghiem <- -b/(2*a)
result <- paste("x1 = x2 = x0 =", nghiem)
} else{
x1 <- (-b + sqrt(delta))/(2*a)
x2 <- (-b - sqrt(delta))/(2*a)
result <- paste("x1 =", x1, ", x2 =", x2)
}
}
return(result)
}

# %%
a <- as.numeric(readline(prompt = "Input a: "))
b <- as.numeric(readline(prompt = "Input b: "))
c <- as.numeric(readline(prompt = "Input c: "))
result = ptb2.function(a,b,c)
print(paste(a,"x^2 +",b,"x +",c, "= 0 => ",result))
# Out:
# Input a: 12
# Input b: 4
# Input c: 5
# [1] "12 x^2 + 4 x + 5 = 0 =>  Phuong trinh vo nghiem"

# %% [markdown]
# **Exercise 3: Xây dựng function**

# %%
#https://drive.google.com/file/d/1YUooyB84kBzA6mbpHllnUiMyE-FonW7b/view?usp=sharing
system("gdown --id 1YUooyB84kBzA6mbpHllnUiMyE-FonW7b")
source("function_1.R") #jupiter_notebook

# %%
so_kw <- as.integer(readline(prompt = "So kw tieu thu: "))

tien_dien = tinh_tien_dien.function(so_kw)
print(paste("Tien dien:", tien_dien, "VND"))
# Out:
# So kw tieu thu: 67
# [1] "Tien dien: 113378 VND"
