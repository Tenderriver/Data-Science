# %%
set1=[]
kt1=True
while kt1:
    set1.append(eval(input("Nhap gia tri set 1: ")))
    kt1=eval(input("Tiep tuc nhap gia tri (1:Co, 2: Khong): "))
set2=[]
kt2=True
while kt2:
    set2.append(eval(input("Nhap gia tri set 2: ")))
    kt2=eval(input("Tiep tuc nhap gia tri (1:Co, 2: Khong): "))
print("Set 1", set1)
print("Set 2", set2)
print("So phan tu set 1: ", len(set1))
print("So phan tu set 2: ", len(set2))
print("Tong set 1: ", sum(set1))
print("Tong set 2: ", sum(set2))
print (f'Max set 1: {max(set1)}, Min set 1: {min(set1)}')
print(set1.pop(2))
print("Set 1 sau khi lay ra 1 phan tu", set1)
print("Set 1 union set 2", set1+set2)
intersection=[]
for i in set1:
    for j in set2:
        if i==j:
            intersection.append(i)
print("Intersection cua set 1 va set 2", intersection)
differ=[]
c=set1[:]
for i in c:
    for j in set2:
        if i==j:
            c.remove(i)
print("Difference cua set 1 voi set 2", c)
a=set1[:]
b=set2[:]
for i in a:
    for j in b:
        if i==j:
            a.remove(i)
            b.remove(j)
print("Symmetric difference cua set 1 va set 2", a+b)
print("Set 1 theo thu tu tang dan", sorted(set1))
print("Set 2 theo thu tu tang dan", sorted(set2))
# Out:
# Nhap gia tri set 1: 2
# Tiep tuc nhap gia tri (1:Co, 2: Khong): 4
# Nhap gia tri set 1: 3
# Tiep tuc nhap gia tri (1:Co, 2: Khong): 1
# Nhap gia tri set 1: 6
# Tiep tuc nhap gia tri (1:Co, 2: Khong): 1
# Nhap gia tri set 1: 5
# Tiep tuc nhap gia tri (1:Co, 2: Khong): 0
# Nhap gia tri set 2: 4
# Tiep tuc nhap gia tri (1:Co, 2: Khong): 1
# Nhap gia tri set 2: 5
# Tiep tuc nhap gia tri (1:Co, 2: Khong): 1
# Nhap gia tri set 2: 10
# Tiep tuc nhap gia tri (1:Co, 2: Khong): 1
# Nhap gia tri set 2: 7
# Tiep tuc nhap gia tri (1:Co, 2: Khong): 0
# Set 1 [2, 3, 6, 5]
# Set 2 [4, 5, 10, 7]
# So phan tu set 1:  4
# So phan tu set 2:  4
# Tong set 1:  16
# Tong set 2:  26
# Max set 1: 6, Min set 1: 2
# 6
# Set 1 sau khi lay ra 1 phan tu [2, 3, 5]
# Set 1 union set 2 [2, 3, 5, 4, 5, 10, 7]
# Intersection cua set 1 va set 2 [5]
# Difference cua set 1 voi set 2 [2, 3]
# Symmetric difference cua set 1 va set 2 [2, 3, 4, 10, 7]
# Set 1 theo thu tu tang dan [2, 3, 5]
# ...

# %%
set1=set()
kt1=True
while kt1:
    set1.add(eval(input("Nhap gia tri set 1: ")))
    kt1=eval(input("Tiep tuc nhap gia tri (1:Co, 2: Khong): "))
set2=set()
kt2=True
while kt2:
    set2.add(eval(input("Nhap gia tri set 2: ")))
    kt2=eval(input("Tiep tuc nhap gia tri (1:Co, 2: Khong): "))
print("Set 1", set1)
print("Set 2", set2)
print("So phan tu set 1: ", len(set1))
print("So phan tu set 2: ", len(set2))
print("Tong set 1: ", sum(set1))
print("Tong set 2: ", sum(set2))
print (f'Max set 1: {max(set1)}, Min set 1: {min(set1)}')
print(set1.pop())
print("Set 1 sau khi lay ra 1 phan tu", set1)
print("Set 1 union set 2", set1|set2)

print("Intersection cua set 1 va set 2", set1&set2)

print("Difference cua set 1 voi set 2", set1-set2)

print("Symmetric difference cua set 1 va set 2", set1^set2)
print("Set 1 theo thu tu tang dan", sorted(set1))
print("Set 2 theo thu tu tang dan", sorted(set2))
# Out:
# Nhap gia tri set 1: 2
# Tiep tuc nhap gia tri (1:Co, 2: Khong): 1
# Nhap gia tri set 1: 4
# Tiep tuc nhap gia tri (1:Co, 2: Khong): 1
# Nhap gia tri set 1: 5
# Tiep tuc nhap gia tri (1:Co, 2: Khong): 1
# Nhap gia tri set 1: 7
# Tiep tuc nhap gia tri (1:Co, 2: Khong): 0
# Nhap gia tri set 2: 8
# Tiep tuc nhap gia tri (1:Co, 2: Khong): 1
# Nhap gia tri set 2: 10
# Tiep tuc nhap gia tri (1:Co, 2: Khong): 1
# Nhap gia tri set 2: 6
# Tiep tuc nhap gia tri (1:Co, 2: Khong): 1
# Nhap gia tri set 2: 7
# Tiep tuc nhap gia tri (1:Co, 2: Khong): 0
# Set 1 {2, 4, 5, 7}
# Set 2 {8, 10, 6, 7}
# So phan tu set 1:  4
# So phan tu set 2:  4
# Tong set 1:  18
# Tong set 2:  31
# Max set 1: 7, Min set 1: 2
# 2
# Set 1 sau khi lay ra 1 phan tu {4, 5, 7}
# Set 1 union set 2 {4, 5, 6, 7, 8, 10}
# Intersection cua set 1 va set 2 {7}
# Difference cua set 1 voi set 2 {4, 5}
# Symmetric difference cua set 1 va set 2 {4, 5, 6, 8, 10}
# Set 1 theo thu tu tang dan [4, 5, 7]
# ...
