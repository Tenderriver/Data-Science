# %%
# Tạo trang R trên colab: https://colab.research.google.com/notebook#create=true&language=r
a <- 5
b <- 7
c <- a + b

# %%
fruit <- c("a",'b','c')

# %%
print(fruit)
# Out:
# [1] "a" "b" "c"

# %%
print(c)
# Out:
# [1] 12

# %% [markdown]
# **Ex2: Life of battery**

# %% [markdown]
# **Bài toán 1**: Một nhà sản xuất đang điều tra tuổi thọ hoạt động của pin
# máy tính xách tay (Battery 1). Các quan sát được liệt kê trong tập tin
# life_batteries.txt.

# %%
#https://drive.google.com/file/d/1DMmIQK3rxGcE47fbNQfWA-5tEhUFJ66q/view?usp=sharing
system('gdown --id 1DMmIQK3rxGcE47fbNQfWA-5tEhUFJ66q')

# %%
df <- read.csv("life_batteries.txt", sep = "\t", header = F)
print("Content of file:")
print(df)
# Out:
# [1] "Content of file:"
#     V1  V2  V3  V4
# 1  130 145 126 146
# 2  164 130 132 152
# 3  145 129 133 155
# 4  140 127 139 137
# 5  131 126 145 148
# 6  125 132 126 126
# 7  126 135 131 129
# 8  147 136 129 136
# 9  156 146 130 146
# 10 132 142 132 132

# %%
data <- c(df$V1, df$V2, df$V3, df$V4)
data
# Out:
#  [1] 130 164 145 140 131 125 126 147 156 132 145 130 129 127 126 132 135 136 146
# [20] 142 126 132 133 139 145 126 131 129 130 132 146 152 155 137 148 126 129 136
# [39] 146 132

# %%
par(mfrow=c(1,2))
hist(data, main = "Life Batteries", xlab = "Hours",
xlim = c(110, max(data)+10), ylim = c(0, 20), col = "orange",
border = "blue", breaks = 5)
# Create the histogram.
hist(data, main = "Life batteries",
xlab = "Hours",
xlim = c(110, max(data)+10),
col = "orange",
breaks = 10,
border = "blue",
# so lieu tren y theo hang ngang
las = 1,
freq=FALSE
)
lines(density(data))
# Out:
# Plot with title “Life batteries”

# %% [markdown]
# Chart này nói lên điều gì?
# Biểu đồ cho thấy hầu hết các dữ liệu được tập trung trong khoảng 130, với một vài điểm dữ
# liệu vượt quá 150. Có thể kết luận rằng trung tâm của dữ liệu là một nơi nào đó trong khoảng
# 130-139.
# Từ hai biểu đồ trên, có thể xác định nhiều biện pháp phân tán và xu hướng trung tâm:

# %%
summary(data)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   125.0   129.8   132.5   136.8   145.0   164.0

# %%
var(data)
# Out:
# [1] 95.87436

# %%
sd(data)
# Out:
# [1] 9.791545

# %%
install.packages("moments")
library("moments")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
skewness(data)
# Out:
# [1] 0.8455287

# %%
kurtosis(data)
# Out:
# [1] 2.923868

# %% [markdown]
# **Bài toán 2**: Xem xét một bộ dữ liệu 40 mẫu khác cho một nhãn hiệu pin
# khác (Battery 2). Các quan sát được liệt kê trong tập tin
# life_batteries_2.txt.

# %%
#https://drive.google.com/file/d/13Ney4PRRmEvF3SSj9NtYQmAqa6uy-5ON/view?usp=sharing
system('gdown --id 13Ney4PRRmEvF3SSj9NtYQmAqa6uy-5ON')

# %%
df2 <- read.csv("life_batteries_2.txt", sep = "\t", header = F)
print("Content of file:")
print(df2)
# Out:
# [1] "Content of file:"
#     V1  V2  V3  V4
# 1  134 130 140 151
# 2  143 134 136 144
# 3  150 135 160 141
# 4  143 140 138 141
# 5  148 146 140 146
# 6  151 138 151 139
# 7  151 128 146 147
# 8  152 142 144 134
# 9  142 146 142 136
# 10 122 134 145 147

# %%
data2 <- c(df2$V1, df2$V2, df2$V3, df2$V4)
data2
# Out:
#  [1] 134 143 150 143 148 151 151 152 142 122 130 134 135 140 146 138 128 142 146
# [20] 134 140 136 160 138 140 151 146 144 142 145 151 144 141 141 146 139 147 134
# [39] 136 147

# %%
par(mfrow=c(1,2))
hist(data2, main = "Life Batteries 2", xlab = "Hours",
xlim = c(110, max(data2)+10), ylim = c(0, 20), col = "orange",
border = "blue", breaks = 5)

hist(data2, main = "Life batteries",
xlab = "Hours",
xlim = c(110, max(data2)+10),
col = "orange",
breaks = 10,
border = "blue",
las = 1,
freq=FALSE
)
lines(density(data2))
# Out:
# Plot with title “Life batteries”

# %% [markdown]
# Chart này nói lên điều gì?
# Biểu đồ trên cho thấy rằng có nhiều dữ liệu hơn cho Battery 2 trong khoảng 140 so với
# Battery 1 trong khoảng 130. Ngoài ra, mức độ biến thiên của Battery 2 ít hơn so với Battery 1.
# Dựa trên các kết quả này, có thể kết luận rằng Battery 2 là một nhãn hiệu tốt hơn (trung bình
# cao hơn và biến thiên thấp hơn). Tuy nhiên, tính hợp lệ của kết luận này còn phụ thuộc vào
# cách thu thập dữ liệu.

# %%
summary(data2)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   122.0   137.5   142.0   141.9   146.2   160.0

# %%
var(data2)
# Out:
# [1] 55.19936

# %%
sd(data2)
# Out:
# [1] 7.429627

# %%
library("moments")
skewness(data2)
# Out:
# [1] -0.2510339

# %%
kurtosis(data2)
# Out:
# [1] 3.356703

# %% [markdown]
# Phân phối cao hơn phân phối chuẩn
#
# Nhận xét:
# Những kết quả này cho thấy rằng Pin 2 có tuổi thọ trung bình cao hơn so với Pin 1 và Pin 2
# có phương sai nhỏ hơn.
# Pin 1 có skewness > 0: phân phối lệch phải
# Pin 2 có skewness < 0: phân phối lệch trái
# Pin 1 có kurtosis < 0: phân bố này thấp hơn phân bố chuẩn
# Pin 2 có kurtosis > 0: phân bố này cao hơn phân bố chuẩn

# %%
par(mfrow=c(1,2))
boxplot(data, main="Pin 1")
boxplot(data2, main="Pin 2")
# Out:
# Plot with title “Pin 2”

# %% [markdown]
# Nhận xét:
# Nhóm Pin 1 không có outliers, nhóm Pin 2 có outliers
# Phân phối Pin 2 tập trung hơn phân phối phin 1
# Biểu đồ ở trên hỗ trợ cho kết luận: phạm vi của Pin 2 ngắn hơn so với Pin 1 (ít thay đổi hơn)
# và được chuyển sang bên phải (trung tâm cao hơn).
