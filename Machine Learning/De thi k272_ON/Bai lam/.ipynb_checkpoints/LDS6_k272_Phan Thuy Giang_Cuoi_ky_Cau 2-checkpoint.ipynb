# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from scipy.special import comb 
from itertools import combinations, permutations

# %%
headers=["Item_1", "Item_2","Item_3","Item_4","Item_5","Item_6","Item_7","Item_8","Item_9", "Item_10"]
df=pd.read_excel('ItemList.xlsx', usecols = "A:J",header=None)

# %%
df.columns=headers
df
# Out:
#                       Item_1              Item_2               Item_3  Item_4  \
# 0                    sausage          whole milk  semi-finished bread  yogurt
# 1                 whole milk              pastry          salty snack     NaN
# 2                canned beer     misc. beverages                  NaN     NaN
# 3                    sausage    hygiene articles                  NaN     NaN
# 4                       soda  pickled vegetables                  NaN     NaN
# ...                      ...                 ...                  ...     ...
# 14958         tropical fruit             berries     other vegetables  yogurt
# 14959          bottled water               herbs                  NaN     NaN
# 14960  fruit/vegetable juice              onions                  NaN     NaN
# 14961                   soda     root vegetables  semi-finished bread     NaN
# 14962           bottled beer    other vegetables                  NaN     NaN
#
#                Item_5   Item_6 Item_7 Item_8 Item_9 Item_10
# 0                 NaN      NaN    NaN    NaN    NaN     NaN
# 1                 NaN      NaN    NaN    NaN    NaN     NaN
# 2                 NaN      NaN    NaN    NaN    NaN     NaN
# 3                 NaN      NaN    NaN    NaN    NaN     NaN
# 4                 NaN      NaN    NaN    NaN    NaN     NaN
# ...               ...      ...    ...    ...    ...     ...
# 14958  kitchen towels  napkins    NaN    NaN    NaN     NaN
# 14959             NaN      NaN    NaN    NaN    NaN     NaN
# 14960             NaN      NaN    NaN    NaN    NaN     NaN
# 14961             NaN      NaN    NaN    NaN    NaN     NaN
# 14962             NaN      NaN    NaN    NaN    NaN     NaN
#
# [14963 rows x 10 columns]

# %%
df_values = df.values.astype(str)
index, counts = np.unique(df_values,return_counts=True)
df_item = pd.DataFrame(zip(index, counts), columns = ['product', 'frequency'])
df_item.drop(df_item[(df_item['product'] == 'nan' )|(df_item['product'] == 'None' )].index, inplace=True)
df_item.sort_values(by='frequency', ascending=False, inplace=True)
df_item.reset_index(drop=True, inplace=True)

# %%
df_item
# Out:
#                    product  frequency
# 0               whole milk       2502
# 1         other vegetables       1898
# 2               rolls/buns       1716
# 3                     soda       1514
# 4                   yogurt       1334
# ..                     ...        ...
# 162        rubbing alcohol          5
# 163                   bags          4
# 164         baby cosmetics          3
# 165  preservation products          1
# 166        kitchen utensil          1
#
# [167 rows x 2 columns]

# %%
Row_list =[]
  
# Iterate over each row
for index, rows in df.iterrows():
    # Create list for the current row
    my_list =[rows.Item_1, rows.Item_2,rows.Item_3,rows.Item_4,rows.Item_5,rows.Item_6,rows.Item_7,rows.Item_8, rows.Item_9,rows.Item_10]
      
    # append the list to the final list
    Row_list.append(my_list)
  
# Print the list
print(Row_list)
# Out:
# [['sausage', 'whole milk', 'semi-finished bread', 'yogurt', nan, nan, nan, nan, nan, nan], ['whole milk', 'pastry', 'salty snack', nan, nan, nan, nan, nan, nan, nan], ['canned beer', 'misc. beverages', nan, nan, nan, nan, nan, nan, nan, nan], ['sausage', 'hygiene articles', nan, nan, nan, nan, nan, nan, nan, nan], ['soda', 'pickled vegetables', nan, nan, nan, nan, nan, nan, nan, nan], ['frankfurter', 'curd', nan, nan, nan, nan, nan, nan, nan, nan], ['sausage', 'whole milk', 'rolls/buns', nan, nan, nan, nan, nan, nan, nan], ['whole milk', 'soda', nan, nan, nan, nan, nan, nan, nan, nan], ['beef', 'white bread', nan, nan, nan, nan, nan, nan, nan, nan], ['frankfurter', 'soda', 'whipped/sour cream', nan, nan, nan, nan, nan, nan, nan], ['frozen vegetables', 'other vegetables', nan