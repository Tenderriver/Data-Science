# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("bmw.csv", sep=",")

# %%
data.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0   5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1   6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2   5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# 3   1 Series  2017  12750    Automatic    26676   Diesel  145  72.4
# 4   7 Series  2014  14500    Automatic    39554   Diesel  160  50.4
#
#    engineSize
# 0         2.0
# 1         2.0
# 2         3.0
# 3         1.5
# 4         3.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10781 entries, 0 to 10780
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10781 non-null  object
#  1   year          10781 non-null  int64
#  2   price         10781 non-null  int64
#  3   transmission  10781 non-null  object
#  4   mileage       10781 non-null  int64
#  5   fuelType      10781 non-null  object
#  6   tax           10781 non-null  int64
#  7   mpg           10781 non-null  float64
#  8   engineSize    10781 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 758.2+ KB

# %%
data.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  10781.000000   10781.000000   10781.000000  10781.000000  10781.000000
# mean    2017.078935   22733.408867   25496.986550    131.702068     56.399035
# std        2.349038   11415.528189   25143.192559     61.510755     31.336958
# min     1996.000000    1200.000000       1.000000      0.000000      5.500000
# 25%     2016.000000   14950.000000    5529.000000    135.000000     45.600000
# 50%     2017.000000   20462.000000   18347.000000    145.000000     53.300000
# 75%     2019.000000   27940.000000   38206.000000    145.000000     62.800000
# max     2020.000000  123456.000000  214000.000000    580.000000    470.800000
#
#          engineSize
# count  10781.000000
# mean       2.167767
# std        0.552054
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        2.000000
# max        6.600000

# %%
data['model'].value_counts()
# Out:
#  3 Series    2443
#  1 Series    1969
#  2 Series    1229
#  5 Series    1056
#  4 Series     995
#  X1           804
#  X3           551
#  X5           468
#  X2           288
#  X4           179
#  M4           125
#  Z4           108
#  6 Series     108
#  X6           106
#  7 Series     106
#  X7            55
#  i3            43
#  8 Series      39
#  M5            29
#  M3            27
#  M2            21
#  i8            17
#  M6             8
#  Z3             7
# Name: model, dtype: int64

# %%
data['transmission'].value_counts()
# Out:
# Semi-Auto    4666
# Automatic    3588
# Manual       2527
# Name: transmission, dtype: int64

# %%
data['fuelType'].value_counts()
# Out:
# Diesel      7027
# Petrol      3417
# Hybrid       298
# Other         36
# Electric       3
# Name: fuelType, dtype: int64

# %%
data['transmission'].replace(to_replace={"Semi-Auto":1,"Automatic":2, "Manual":3},inplace=True)

# %%
data['fuelType'].replace(to_replace={"Diesel":1,"Petrol":2, "Hybrid":3, "Other":4, "Electric": 5},inplace=True)

# %%
data.head()
# Out:
#        model  year  price  transmission  mileage  fuelType  tax   mpg  \
# 0   5 Series  2014  11200             2    67068         1  125  57.6
# 1   6 Series  2018  27000             2    14827         2  145  42.8
# 2   5 Series  2016  16000             2    62794         1  160  51.4
# 3   1 Series  2017  12750             2    26676         1  145  72.4
# 4   7 Series  2014  14500             2    39554         1  160  50.4
#
#    engineSize
# 0         2.0
# 1         2.0
# 2         3.0
# 3         1.5
# 4         3.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10781 entries, 0 to 10780
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10781 non-null  object
#  1   year          10781 non-null  int64
#  2   price         10781 non-null  int64
#  3   transmission  10781 non-null  int64
#  4   mileage       10781 non-null  int64
#  5   fuelType      10781 non-null  int64
#  6   tax           10781 non-null  int64
#  7   mpg           10781 non-null  float64
#  8   engineSize    10781 non-null  float64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 758.2+ KB

# %%
sns.pairplot(data, kind="scatter")
plt.show()

# %%
plt.figure(figsize=(10,7))
corr = data.corr()
sns.heatmap(corr, cbar=True, annot = True);

# %%
X = data.drop(columns=['engineSize','model'])
y = data['engineSize']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVC

# %%
from sklearn.metrics import mean_squared_error

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn import metrics
def cross_val(model):
    pred = cross_val_score(model, X, y, cv=10)
    return pred.mean()

def print_evaluate(true, predicted):  
    mae = metrics.mean_absolute_error(true, predicted)
    mse = metrics.mean_squared_error(true, predicted)
    rmse = np.sqrt(metrics.mean_squared_error(true, predicted))
    r2_square = metrics.r2_score(true, predicted)
    print('MAE:', mae)
    print('MSE:', mse)
    print('RMSE:', rmse)
    print('R2 Square', r2_square)
    print('__________________________________')
    
def evaluate(true, predicted):
    mae = metrics.mean_absolute_error(true, predicted)
    mse = metrics.mean_squared_error(true, predicted)
    rmse = np.sqrt(metrics.mean_squared_error(true, predicted))
    r2_square = metrics.r2_score(true, predicted)
    return mae, mse, rmse, r2_square

# %%
lin_reg = LinearRegression(normalize=True)
lin_reg.fit(X_train,y_train)
pred = lin_reg.predict(X_test)

# %%
test_pred = lin_reg.predict(X_test)
train_pred = lin_reg.predict(X_train)

print('Test set evaluation:\n_____________________________________')
print_evaluate(y_test, test_pred)
print('Train set evaluation:\n_____________________________________')
print_evaluate(y_train, train_pred)
# Out:
# Test set evaluation:
# _____________________________________
# MAE: 0.29042929011820817
# MSE: 0.14722837832971497
# RMSE: 0.3837035031501732
# R2 Square 0.5483743639044527
# __________________________________
# Train set evaluation:
# _____________________________________
# MAE: 0.28402872037535226
# MSE: 0.14139951428764982
# RMSE: 0.37603126769944256
# R2 Square 0.5213989630460264
# __________________________________

# %%
results_df = pd.DataFrame(data=[["Linear Regression", *evaluate(y_test, test_pred) , cross_val(LinearRegression())]], 
                          columns=['Model', 'MAE', 'MSE', 'RMSE', 'R2 Square', "Cross Validation"])
results_df
# Out:
#                Model       MAE       MSE      RMSE  R2 Square  \
# 0  Linear Regression  0.290429  0.147228  0.383704   0.548374
#
#    Cross Validation
# 0          0.519893

# %%
rf_reg = RandomForestRegressor(n_estimators=1000)
rf_reg.fit(X_train, y_train)

test_pred = rf_reg.predict(X_test)
train_pred = rf_reg.predict(X_train)

print('Test set evaluation:\n_____________________________________')
print_evaluate(y_test, test_pred)

print('Train set evaluation:\n_____________________________________')
print_evaluate(y_train, train_pred)
# Out:
# Test set evaluation:
# _____________________________________
# MAE: 0.08661489953632125
# MSE: 0.044254074905718636
# RMSE: 0.21036652515483217
# R2 Square 0.864249848053367
# __________________________________
# Train set evaluation:
# _____________________________________
# MAE: 0.0285435064935063
# MSE: 0.0057595194076331055
# RMSE: 0.07589149759777511
# R2 Square 0.9805055061558263
# __________________________________

# %%
results_df_2 = pd.DataFrame(data=[["Random Forest Regressor", *evaluate(y_test, test_pred), 0]], 
                            columns=['Model', 'MAE', 'MSE', 'RMSE', 'R2 Square', 'Cross Validation'])
results_df = results_df.append(results_df_2, ignore_index=True)
results_df
# Out:
#                      Model       MAE       MSE      RMSE  R2 Square  \
# 0        Linear Regression  0.290429  0.147228  0.383704   0.548374
# 1  Random Forest Regressor  0.086615  0.044254  0.210367   0.864250
#
#    Cross Validation
# 0          0.519893
# 1          0.000000
