# %% [markdown]
# ## Chapter 6 - Exercise 5: WordClouds

# %% [markdown]
# #### Thực hiện các yêu cầu sau, và đối chiếu với kết quả cho trước:

# %% [markdown]
# ### Part 1:

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
from PIL import Image

# %%
# Tạo dataframe df từ file dữ liệu Youtube04-Eminem.csv, in vài dòng dữ liệu đầu của df
df=pd.read_csv('Youtube04-Eminem.csv')
df.head()
# Out:
#                             COMMENT_ID         AUTHOR  \
# 0    z12rwfnyyrbsefonb232i5ehdxzkjzjs2    Lisa Wellas
# 1  z130wpnwwnyuetxcn23xf5k5ynmkdpjrj04   jason graham
# 2    z13vsfqirtavjvu0t22ezrgzyorwxhpf3     Ajkal Khan
# 3  z12wjzc4eprnvja4304cgbbizuved35wxcs  Dakota Taylor
# 4    z13xjfr42z3uxdz2223gx5rrzs3dt5hna    Jihad Naser
#
#                          DATE  \
# 0                         NaN
# 1  2015-05-29T02:26:10.652000
# 2                         NaN
# 3  2015-05-29T02:13:07.810000
# 4                         NaN
#
#                                              CONTENT  CLASS
# 0          +447935454150 lovely girl talk to me xxx﻿      1
# 1    I always end up coming back to this song<br />﻿      0
# 2  my sister just received over 6,500 new <a rel=...      1
# 3                                              Cool﻿      0
# 4                     Hello I&#39;am from Palastine﻿      1

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <pre>0           +447935454150 lovely girl talk to me xxxï»¿
# 1     I always end up coming back to this song&lt;br /&gt;ï»¿
# 2     my sister just received over 6,500 new &lt;a rel=...
# 3                                               Coolï»¿
# 4                      Hello I&amp;#39;am from Palastineï»¿
# 5     Wow this video almost has a billion views! Did...
# 6     Go check out my rapping video called Four Whee...
# 7                                   Almost 1 billionï»¿
# 8                      Aslamu Lykum... From Pakistanï»¿
# 9     Eminem is idol for very people in EspaÃ±a and ...
# 10                       Help me get 50 subs please ï»¿
# 11                                    i love song :)ï»¿
# 12    Alright ladies, if you like this song, then ch...
# 13    The perfect example of abuse from husbands and...
# 14    The boyfriend was Charlie from the TV show LOS...
# 15    &lt;a href="https://www.facebook.com/groups/10087...
# 16             Take a look at this video on YouTube:ï»¿
# 17            Check out our Channel for nice Beats!!ï»¿
# 18      Rihanna and Eminem together are unstoppable.ï»¿
# 19               Check out this playlist on YouTube:ï»¿
# Name: CONTENT, dtype: object</pre>
#
# </details>

# %%
# Hãy bỏ các STOPWORD
stopwords=set(STOPWORDS)
type(stopwords)
# Out:
# set

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div class="output_subarea output_text output_result"><pre>{'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'also',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  "can't",
#  'cannot',
#  'com',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'else',
#  'ever',
#  'few',
#  'for',
#  'from',
#  'further',
#  'get',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'hence',
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'however',
#  'http',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'k',
#  "let's",
#  'like',
#  'me',
#  'more',
#  'most',
#  "mustn't",
#  'my',
#  'myself',
#  'no',
#  'nor',
#  'not',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'otherwise',
#  'ought',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'r',
#  'same',
#  'shall',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  "shouldn't",
#  'since',
#  'so',
#  'some',
#  'such',
#  'than',
#  'that',
#  "that's",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  "there's",
#  'therefore',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  'very',
#  'was',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'were',
#  "weren't",
#  'what',
#  "what's",
#  'when',
#  "when's",
#  'where',
#  "where's",
#  'which',
#  'while',
#  'who',
#  "who's",
#  'whom',
#  'why',
#  "why's",
#  'with',
#  "won't",
#  'would',
#  "wouldn't",
#  'www',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}</pre></div>
#
# </details>

# %%
text=df['CONTENT'].to_string()
text
# Out:
# '0              +447935454150 lovely girl talk to me xxx\ufeff\n1        I always end up coming back to this song<br />\ufeff\n2      my sister just received over 6,500 new <a rel=...\n3                                                  Cool\ufeff\n4                         Hello I&#39;am from Palastine\ufeff\n5      Wow this video almost has a billion views! Did...\n6      Go check out my rapping video called Four Whee...\n7                                      Almost 1 billion\ufeff\n8                         Aslamu Lykum... From Pakistan\ufeff\n9      Eminem is idol for very people in España and M...\n10                          Help me get 50 subs please \ufeff\n11                                       i love song :)\ufeff\n12     Alright ladies, if you like this song, then ch...\n13     The perfect example of abuse from husbands and...\n14     The boyfriend was Charlie from the TV show LOST \ufeff\n15     <a href="https://www.facebook.com/groups/10087...\n16                Take a look at this video on YouTube:\ufeff\n17               Check out our Channel for nice Beats!!\ufeff\n18         Rihanna and Eminem together are unstoppable.\ufeff\n19                  Check out this playlist on YouTube:\ufeff\n20     This song is about Rape and Cheating \xa0 \xa0\xa0<br /...\n21                                          like please\ufeff\n22     I love this song, can&#39;t believe it was 5 y...\n23     OMG that looks just like a piece of the mirror...\n24     I shared my first song &quot;I Want You&quot;,...\n25     Come and check out my music!Im spamming on loa...\n26                  Check out this playlist on YouTube:\ufeff\n27     HUH HYUCK HYUCK IM SPECIAL WHO&#39;S WATCHING ...\n28     You exactly who u want to be,watching your fav...\n29        Rihanna is absolutely gorgeous in this video.\ufeff\n30     Check out this video on YouTube:<br /><br />Lo...\n31     Don&#39;t love someone soo much, love the way ...\n32               one of the BEST SONGS in music history\ufeff\n33                  Check out this playlist on YouTube:\ufeff\n34                     Check out this video on YouTube:\ufeff\n35                     Check out this video on YouTube:\ufeff\n36                            No-I hate The Way U LIe!!\ufeff\n37                Fuck Eminem. Bieber is the best &lt;3\ufeff\n38     Check out this playlist on YouTube:chcfcvzfzfb...\n39                 Check out this playlist on YouTube: \ufeff\n40     Im gonna share a little ryhme canibus blows em...\n41                     Check out this video on YouTube:\ufeff\n42     Check out this video on YouTube<br /><br /><br...\n43      CHECK OUT THE NEW REMIX !!!<br />CLICK CLICK !!\ufeff\n44                  Check out this playlist on YouTube:\ufeff\n45     I personally have never been in a abusive rela...\n46                                              Love😘❤💖\ufeff\n47     Haha, I can&#39;t believe how many kids listen...\n48                                plese subscribe to me\ufeff\n49                     Check out this video on YouTube:\ufeff\n50     Aye homies check out our remix to 50 Cent Your...\n51     this is the 2nd most best song when im gone by...\n52                     Check out this video on YouTube:\ufeff\n53                   WE GO FOR 1,000,000,000 FOR EMINEM\ufeff\n54          Eminem and Rihanna sing the song very well.\ufeff\n55                        Subscribe me Secret videos :D\ufeff\n56                     Check out this video on YouTube:\ufeff\n57     Check out this video on YouTube:but I&#39;m no...\n58                     Subscribe to me for clean Eminem!\n59      Hey youtubers... {**}I really appreciate all ...\n60                        LOVE THE WAY YOU LIE ..&quot;\ufeff\n61                     Check out this video on YouTube:\ufeff\n62     This guy win dollars sleeping... m m m he love...\n63                     Check out our cover of this song!\n64                     Check out this video on YouTube:\ufeff\n65                                  ...

# %%
df1=' '.join(df['CONTENT'])
type(df1)
# Out:
# str

# %%
# Vẽ WordClouds cho dữ liệu này
wordcloud=wordcloud = WordCloud(width = 800, height = 800,background_color ='white',stopwords = stopwords,min_font_size = 10).generate(df1)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
df = pd.read_csv(r"Youtube04-Eminem.csv", encoding ="latin-1")
 
comment_words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for val in df.CONTENT:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div class="output_subarea output_png"><img src="data:image/png;base64,...
# "></div>
#
# </details>

# %% [markdown]
# ### Part 2:

# %%
# Sử dụng vietnamese stop word từ : https://github.com/stopwords/vietnamese-stopwords => tạo thành set các stop words
stopword_vn=set(map(str.rstrip,open('vietnamese-stopwords.txt',"r",encoding='utf-8')))

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div class="output_subarea output_text output_result"><pre>{'a ha',
#  'ai ai',
#  'ai đó',
#  'amen',
#  'anh ấy',
#  'ba ba',
#  'ba cùng',
#  'ba ngày',
#  'ba tăng',
#  'bao lâu',
#  'bao nả',
#  'biết',
#  'biết bao nhiêu',
#  'biết chừng nào',
#  'biết mấy',
#  'biết trước',
#  'biết đâu',
#  'biết đâu đấy',
#  'buổi',
#  'buổi mới',
#  'buổi sớm',
#  'bà ấy',
#  'bài bác',
#  'bài cái',
#  'bán',
#  'bán dạ',
#  'bây bẩy',
#  'bây giờ',
#  'bèn',
#  'bên',
#  'bên có',
#  'bông',
#  'bước khỏi',
#  'bước đi',
#  'bản',
#  'bản riêng',
#  'bản ý',
#  'bất cứ',
#  'bất kì',
#  'bất kỳ',
#  'bất ngờ',
#  'bất quá',
#  'bất thình lình',
#  'bất đồ',
#  'bấy chầy',
#  'bấy giờ',
#  'bấy lâu nay',
#  'bấy nhiêu',
#  'bập bõm',
#  'bắt đầu từ',
#  'bằng cứ',
#  'bằng người',
#  'bằng như',
#  'bằng nấy',
#  'bằng được',
#  'bển',
#  'bị',
#  'bị vì',
#  'bỏ bà',
#  'bỏ cuộc',
#  'bỏ lại',
#  'bỏ mất',
#  'bỏ nhỏ',
#  'bỏ ra',
#  'bỏ việc',
#  'bỗng',
#  'bỗng dưng',
#  'bỗng nhiên',
#  'bỗng thấy',
#  'bộ',
#  'bộ điều',
#  'bớ',
#  'bởi ai',
#  'bởi nhưng',
#  'bởi thế',
#  'bởi tại',
#  'bởi vậy',
#  'bức',
#  'cao lâu',
#  'cao răng',
#  'cao số',
#  'cao thế',
#  'cha',
#  'chao ôi',
#  'chiếc',
#  'cho biết',
#  'cho hay',
#  'cho nên',
#  'cho rồi',
#  'cho tin',
#  'cho tới khi',
#  'cho ăn',
#  'cho được',
#  'cho đến khi',
#  'choa',
#  'chui cha',
#  'chung cho',
#  'chung cuộc',
#  'chung nhau',
#  'chung quy',
#  'chung ái',
#  'chuyển tự',
#  'chuyện',
#  'chành chạnh',
#  'chính',
#  'chính giữa',
#  'chính thị',
#  'chùn chùn',
#  'chú',
#  'chú khách',
#  'chú mình',
#  'chúng mình',
#  'chúng tôi',
#  'chăn chắn',
#  'chăng chắc',
#  'chơi',
#  'chưa',
#  'chưa chắc',
#  'chưa cần',
#  'chưa dễ',
#  'chưa tính',
#  'chầm chập',
#  'chắc',
#  'chắc dạ',
#  'chắc lòng',
#  'chắc vào',
#  'chẳng lẽ',
#  'chẳng nữa',
#  'chết nỗi',
#  'chết tiệt',
#  'chỉ chính',
#  'chỉ là',
#  'chỉn',
#  'chị bộ',
#  'chịu',
#  'chịu lời',
#  'chịu ăn',
#  'chọn bên',
#  'chốc chốc',
#  'chớ chi',
#  'chớ không',
#  'chớ như',
#  'chợt nghe',
#  'chủn',
#  'chứ ai',
#  'chứ gì',
#  'chứ không phải',
#  'chứ lị',
#  'chứ sao',
#  'coi mòi',
#  'con con',
#  'con nhà',
#  'cu cậu',
#  'cuối cùng',
#  'cuốn',
#  'càng',
#  'càng hay',
#  'các',
#  'cách',
#  'cách không',
#  'cách đều',
#  'cái gì',
#  'cái đã',
#  'cái ấy',
#  'cây',
#  'còn',
#  'còn nữa',
#  'còn về',
#  'có ai',
#  'có chăng',
#  'có chứ',
#  'có dễ',
#  'có khi',
#  'có người',
#  'có nhà',
#  'có số',
#  'có thế',
#  'có vẻ',
#  'có ăn',
#  'có điều kiện',
#  'có đâu',
#  'cóc khô',
#  'cô mình',
#  'cô tăng',
#  'công nhiên',
#  'cùng chung',
#  'cùng nhau',
#  'cùng tột',
#  'cùng ăn',
#  'căn cái',
#  'căn tính',
#  'cũng như',
#  'cũng thế',
#  'cũng vậy thôi',
#  'cơ',
#  'cơ chừng',
#  'cơ dẫn',
#  'cơ hội',
#  'cơn',
#  'cả nghe',
#  'cả ngày',
#  'cả nhà',
#  'cả thảy',
#  'cả tin',
#  'cả đến',
#  'cảm ơn',
#  'cấp số',
#  'cần',
#  'cần gì',
#  'cật lực',
#  'cậu',
#  'cụ thể',
#  'cụ thể như',
#  'của ngọt',
#  'cứ',
#  'cứ việc',
#  'cực lực',
#  'do vì',
#  'do đó',
#  'duy chỉ',
#  'dài',
#  'dài ra',
#  'dành dành',
#  'dì',
#  'dù cho',
#  'dù gì',
#  'dù sao',
#  'dùng cho',
#  'dùng làm',
#  'dưới',
#  'dạ',
#  'dạ con',
#  'dạ dạ',
#  'dần dà',
#  'dầu sao',
#  'dẫu',
#  'dẫu rằng',
#  'dễ',
#  'dễ gì',
#  'dễ nghe',
#  'dễ như chơi',
#  'dễ sử dụng',
#  'dễ thấy',
#  'dễ đâu',
#  'dữ',
#  'em',
#  'giá trị',
#  'giảm',
#  'giảm thấp',
#  'giống',
#  'giống nhau',
#  'giờ',
#  'giờ này',
#  'giờ đây',
#  'giữ',
#  'giữ ý',
#  'giữa lúc',
#  'gây cho',
#  'gây ra',
#  'gì',
#  'gì đó',
#  'gần bên',
#  'gần ngày',
#  'gần xa',
#  'gần đến',
#  'gặp khó khăn',
#  'gồm',
#  'hay biết',
#  'hay không',
#  'hay làm',
#  'hay nói',
#  'hay tin',
#  'hiểu',
#  'hiện tại',
#  'hoặc',
#  'hãy',
#  'hơn',
#  'hơn hết',
#  'hơn nữa',
#  'hầu hết',
#  'hết chuyện',
#  'hết của',
#  'hết ráo',
#  'hết ý',
#  'họ gần',
#  'hỏi',
#  'hỏi xem',
#  'hỗ trợ',
#  'khi khác',
#  'khi nào',
#  'khi trước',
#  'khoảng',
#  'khoảng không',
#  'khá tốt',
#  'khác gì',
#  'khác nhau',
#  'khác thường',
#  'khách',
#  'khó biết',
#  'khó khăn',
#  'khó mở',
#  'khó nghĩ',
#  'khó thấy',
#  'không',
#  'không bao giờ',
#  'không biết',
#  'không chỉ',
#  'không có',
#  'không cùng',
#  'không cứ',
#  'không gì',
#  'không khỏi',
#  'không ngoài',
#  'không những',
#  'không phải không',
#  'không tính',
#  'không được',
#  'không để',
#  'khỏi',
#  'kể',
#  'kể như',
#  'kể từ',
#  'loại',
#  'luôn',
#  'luôn luôn',
#  'là',
#  'là là',
#  'là phải',
#  'là vì',
#  'làm',
#  'làm cho',
#  'làm gì',
#  'làm lại',
#  'làm mất',
#  'làm như',
#  'làm ra',
#  'làm sao',
#  'làm thế nào',
#  'làm tôi',
#  'làm tại',
#  'làm vì',
#  'làm được',
#  'lâu các',
#  'lâu nay',
#  'lên',
#  'lên cơn',
#  'lên ngôi',
#  'lên số',
#  'lên đến',
#  'lòng không',
#  'lúc khác',
#  'lúc nào',
#  'lúc sáng',
#  'lúc đi',
#  'lúc đến',
#  'lý do',
#  'lượng cả',
#  'lượng từ',
#  'lại bộ',
#  'lại còn',
#  'lại làm',
#  'lại nói',
#  'lại quả',
#  'lại ăn',
#  'lấy',
#  'lấy cả',
#  'lấy làm',
#  'lấy lại',
#  'lấy ráo',
#  'lấy số',
#  'lấy thế',
#  'lấy xuống',
#  'lấy để',
#  'lần khác',
#  'lần nào',
#  'lần sang',
#  'lần theo',
#  'lần tìm',
#  'lớn lên',
#  'lời',
#  'lời nói',
#  'mang lại',
#  'mang nặng',
#  'muốn',
#  'mà cả',
#  'mà lại',
#  'mà vẫn',
#  'mạnh',
#  'mất còn',
#  'mọi giờ',
#  'mọi lúc',
#  'mọi nơi',
#  'mọi thứ',
#  'mối',
#  'mỗi lúc',
#  'mỗi một',
#  'mỗi người',
#  'một cách',
#  'một khi',
#  'một số',
#  'một ít',
#  'mới hay',
#  'mới đây',
#  'mở mang',
#  'mở ra',
#  'mức',
#  'ngay',
#  'ngay cả',
#  'ngay khi đến',
#  'ngay lúc này',
#  'ngay thật',
#  'ngay tức thì',
#  'nghe',
#  'nghe hiểu',
#  'nghe lại',
#  'nghe như',
#  'nghe ra',
#  'nghe thấy',
#  'nghe trực tiếp',
#  'nghe đâu như',
#  'nghen',
#  'nghĩ',
#  'nghĩ ra',
#  'nghĩ xa',
#  'nghỉm',
#  'ngoài này',
#  'ngoài xa',
#  'nguồn',
#  'ngày càng',
#  'ngày giờ',
#  'ngày nào',
#  'ngày nọ',
#  'ngày rày',
#  'ngày xưa',
#  'ngày đến',
#  'ngôi',
#  'ngôi thứ',
#  'ngăn ngắt',
#  'người',
#  'người khác',
#  'người mình',
#  'người người',
#  'ngọn',
#  'ngọt',
#  'ngồi bệt',
#  'ngồi sau',
#  'ngộ nhỡ',
#  'nhanh lên',
#  'nhau',
#  'nhiều',
#  'nhiệt liệt',
#  'nhà',
#  'nhà khó',
#  'nhà ngoài',
#  'nhà tôi',
#  'nhân dịp',
#  'nhé',
#  'nhìn chung',
#  'nhìn nhận',
#  'nhìn thấy',
#  'nhóm',
#  'như',
#  'như chơi',
#  'như là',
#  'như quả',
#  'như thường',
#  'như thế nào',
#  'như trên',
#  'như tuồng',
#  'như ý',
#  'nhưng mà',
#  'nhất',
#  'nhất luật',
#  'nhất mực',
#  'nhất quyết',
#  'nhất thiết',
#  'nhất tâm',
#  'nhất đán',
#  'nhận',
#  'nhận họ',
#  'nhận nhau',
#  'nhận thấy',
#  'nhận được',
#  'nhằm khi',
#  'nhằm vào',
#  'nhỉ',
#  'nhỏ người',
#  'nhớ bập bõm',
#  'nhớ lấy',
#  'nhờ',
#  'nhờ có',
#  'nhờ đó',
#  'những',
#  'những khi',
#  'những lúc',
#  'những như',
#  'nào cũng',
#  'nào là',
#  'nào đâu',
#  'này',
#  'nên',
#  'nên chăng',
#  'nên người',
#  'nó',
#  'nói',
#  'nói chung',
#  'nói là',
#  'nói lại',
#  'nói phải',
#  'nói ra',
#  'nói rõ',
#  'nói thật',
#  'nói trước',
#  'nói với',
#  'nói ý',
#  'nói đủ',
#  'năm tháng',
#  'nơi nơi',
#  'nước bài',
#  'nước lên',
#  'nước quả',
#  'nước ăn',
#  'nấy',
#  'nặng căn',
#  'nặng về',
#  'nếu có',
#  'nếu không',
#  'nếu như',
#  'nếu vậy',
#  'nền',
#  'nớ',
#  'nữa',
#  'nữa là',
#  'oai oái',
#  'pho',
#  'phè phè',
#  'phía bên',
#  'phía dưới',
#  'phía trong',
#  'phía trước',
#  'phót',
#  'phăn phắt',
#  'phải',
#  'phải chi',
#  'phải cách',
#  'phải giờ',
#  'phải không',
#  'phải lời',
#  'phải như',
#  'phải tay',
#  'phần lớn',
#  'phần nào',
#  'phần việc',
#  'phỉ phui',
#  'phỏng như',
#  'phỏng theo',
#  'phốc',
#  'phứt',
#  'qua chuyện',
#  'qua lại',
#  'qua ngày',
#  'qua thì',
#  'quan trọng',
#  'quan tâm',
#  'quay bước',
#  'quay số',
#  'quá',
#  'quá bộ',
#  'quá lời',
#  'quá nhiều',
#  'quá thì',
#  'quá trình',
#  'quá đáng',
#  'quả',
#  'quả thật',
#  'quả vậy',
#  'ra',
#  'ra bộ',
#  'ra gì',
#  'ra lời',
#  'ra người',
#  'ra tay',
#  'ra ý',
#  'ra đây',
#  'riu ríu',
#  'riêng từng',
#  'rày',
#  'ráo cả',
#  'ráo trọi',
#  'rén bước',
#  'rón rén',
#  'rõ là',
#  'rút cục',
#  'răng răng',
#  'rất lâu',
#  'rằng là',
#  'rốt cục',
#  'rồi nữa',
#  'rồi sao',
#  'rồi tay',
#  'rồi xem',
#  'rứa',
#  'sang',
#  'sang sáng',
#  'sao',
#  'sao bằng',
#  'sao vậy',
#  'sau',
#  'sau cuối',
#  'sau hết',
#  'sau nữa',
#  'sau đây',
#  'so',
#  'song le',
#  'suýt nữa',
#  'sáng ngày',
#  'sáng thế',
#  'sì',
#  'sất',
#  'sắp đặt',
#  'sẽ biết',
#  'số',
#  'số cụ thể',
#  'số là',
#  'số phần',
#  'sốt sột',
#  'sớm ngày',
#  'sử dụng',
#  'sự thế',
#  'tanh',
#  'tay',
#  'tha hồ',
#  'tha hồ ăn',
#  'thanh',
#  'thanh chuyển',
#  'thanh thanh',
#  'thanh điều kiện',
#  'thay đổi',
#  'theo',
#  'theo như',
#  'thi thoảng',
#  'thiếu gì',
#  'thoạt',
#  'thoạt nhiên',
#  'thuần',
#  'thuộc',
#  'thuộc cách',
#  'thuộc từ',
#  'thà là',
#  'thành ra',
#  'thái quá',
#  'tháng ngày',
#  'tháng tháng',
#  'thêm chuyện',
#  'thêm vào',
#  'thì giờ',
#  'thì phải',
#  'thì thôi',
#  'thích',
#  'thích thuộc',
#  'thích ý',
#  'thôi',
#  'thúng thắng',
#  'thường',
#  'thường hay',
#  'thường số',
#  'thường thôi',
#  'thường tính',
#  'thường xuất hiện',
#  'thảo hèn',
#  'thấp',
#  'thấp thỏm',
#  'thấy',
#  'thẩy',
#  'thậm chí',
#  'thậm từ',
#  'thật chắc',
#  'thật lực',
#  'thật ra',
#  'thật thà',
#  'thật vậy',
#  'thế chuẩn bị',
#  'thế lại',
#  'thế nào',
#  'thế ra',
#  'thế thì',
#  'thế thường',
#  'thế à',
#  'thếch',
#  'thỏm',
#  'thốc tháo',
#  'thốt nhiên',
#  'thốt thôi',
#  'thời gian',
#  'thời gian tính',
#  'thục mạng',
#  'thứ bản',
#  'thửa',
#  'thực hiện đúng',
#  'thực sự',
#  'thực vậy',
#  'tin thêm',
#  'tiếp theo',
#  'tiếp đó',
#  'toà',
#  'toẹt',
#  'trong khi',
#  'trong mình',
#  'trong này',
#  'trong vùng',
#  'trong ấy',
#  'tránh khỏi',
#  'tránh tình trạng',
#  'trên',
#  'trên dưới',
#  'trước hết',
#  'trước kia',
#  'trước ngày',
#  'trước sau',
#  'trước tuổi',
#  'trước đó',
#  'trả của',
#  'trả ngay',
#  'trếu tráo',
#  'trệt',
#  'trỏng',
#  'trở thành',
#  'trực tiếp',
#  'tuy',
#  'tuy là',
#  'tuy rằng',
#  'tuy vậy',
#  'tuyệt nhiên',
#  'tuốt luốt',
#  'tuốt tuột',
#  'tuổi cả',
#  'tà tà',
#  'tên chính',
#  'tên họ',
#  'tênh',
#  'tìm',
#  'tìm cách',
#  'tìm ra',
#  'tình trạng',
#  'tính cách',
#  'tính người',
#  'tính từ',
#  'tò te',
#  'tôi con',
#  'tù tì',
#  'tăng',
#  'tăng cấp',
#  'tăng thêm',
#  'tại',
#  'tại nơi',
#  'tại tôi',
#  'tại đâu',
#  'tại đó',
#  'tạo cơ hội',
#  'tạo ra',
#  'tạo điều kiện',
#  'tấm bản',
#  'tấn',
#  'tất cả',
#  'tất thảy',
#  'tất tật',
#  'tắp',
#  'tắp tắp',
#  'tỏ ra',
#  'tốc tả',
#  'tốt',
#  'tốt bộ',
#  'tốt mối',
#  'tột',
#  'tớ',
#  'tới gần',
#  'tới nơi',
#  'tức thì',
#  'từ',
#  'từ giờ',
#  'từ loại',
#  'từ thế',
#  'từ tại',
#  'từ ái',
#  'từ đó',
#  'từng',
#  'từng giờ',
#  'từng phần',
#  'từng đơn vị',
#  'tự',
#  'tự khi',
#  'tự tính',
#  'tự vì',
#  'tự ăn',
#  'veo',
#  'việc',
#  'vung thiên địa',
#  'vung tán tàn',
#  'vài',
#  'vài người',
#  'vài nơi',
#  'vài điều',
#  'vào gặp',
#  'vào lúc',
#  'vào đến',
#  'vâng chịu',
#  'vâng vâng',
#  'vèo',
#  'vì',
#  'vì rằng',
#  'vì thế',
#  'ví bằng',
#  'ví phỏng',
#  'vô hình trung',
#  'vô luận',
#  'vùng',
#  'vùng nước',
#  'vượt',
#  'vượt quá',
#  'vả chăng',
#  'vấn đề',
#  'vẫn',
#  'vậy',
#  'vậy mà',
#  'vậy ra',
#  'vậy ư',
#  'về không',
#  'về phần',
#  'về tay',
#  'vị tất',
#  'với',
#  'với nhau',
#  'vụt',
#  'vừa khi',
#  'vừa mới',
#  'vừa rồi',
#  'xa',
#  'xa gần',
#  'xa tanh',
#  'xa xa',
#  'xem',
#  'xem ra',
#  'xin',
#  'xin vâng',
#  'xon xón',
#  'xoét',
#  'xoẹt',
#  'xuất kì bất ý',
#  'xuể',
#  'xăm xúi',
#  'xăm xắm',
#  'xềnh xệch',
#  'xử lý',
#  'à',
#  'à ơi',
#  'ào vào',
#  'á',
#  'ái',
#  'ái dà',
#  'áng như',
#  'ít',
#  'ít có',
#  'ít khi',
#  'ít nhiều',
#  'ít nữa',
#  'ít ra',
#  'ít thấy',
#  'ô hô',
#  'ô kìa',
#  'ôi thôi',
#  'ông nhỏ',
#  'ông từ',
#  'ông ổng',
#  'úi chà',
#  'ý',
#  'ý da',
#  'ăn',
#  'ăn chắc',
#  'ăn cuộc',
#  'ăn hỏi',
#  'ăn người',
#  'ăn quá',
#  'ăn sáng',
#  'ăn trên',
#  'đang',
#  'đang thì',
#  'điều gì',
#  'điểm',
#  'điểm gặp',
#  'đành đạch',
#  'đáng kể',
#  'đáng lý',
#  'đáng số',
#  'đánh đùng',
#  'đâu',
#  'đâu cũng',
#  'đâu nào',
#  'đâu đâu',
#  'đâu đó',
#  'đây này',
#  'đây đó',
#  'đã hay',
#  'đã là',
#  'đã thế',
#  'đã đủ',
#  'đó đây',
#  'đúng ngày',
#  'đúng tuổi',
#  'đơn vị',
#  'đưa cho',
#  'đưa em',
#  'đưa tay',
#  'đưa tới',
#  'đưa về',
#  'đưa đến',
#  'được cái',
#  'được nước',
#  'đại loại',
#  'đại phàm',
#  'đạt',
#  'đầu tiên',
#  'đầy năm',
#  'đầy tuổi',
#  'đặt',
#  'đặt mình',
#  'đặt ra',
#  'đặt để',
#  'đến bao giờ',
#  'đến cùng cực',
#  'đến giờ',
#  'đến hay',
#  'đến lúc',
#  'đến nay',
#  'đến nơi',
#  'đến thì',
#  'đến tuổi',
#  'đến điều',
#  'đều',
#  'đều nhau',
#  'để',
#  'để giống',
#  'để lòng',
#  'để mà',
#  'để được',
#  'đối với',
#  'đủ',
#  'đủ nơi',
#  'đủ điều',
#  'ơ',
#  'ơ kìa',
#  'ơi là',
#  'ạ',
#  'ấy',
#  'ầu ơ',
#  'ắt hẳn',
#  'ắt phải',
#  'ối dào',
#  'ối giời ơi',
#  'ồ ồ',
#  'ớ',
#  'ờ',
#  'ở',
#  'ở như',
#  'ở năm',
#  'ở vào',
#  'ở đó',
#  'ủa',
#  'ứ ừ',
#  'ừ nhé',
#  'ừ ào',
#  'ử'}</pre></div>
#
# </details>

# %%
stopword_vn_1=pd.read_csv('vietnamese-stopwords.txt',sep='\n',header=None)
a=set(stopword_vn_1[0])

# %%
stopword_vn_2=set(line.strip() for line in open('vietnamese-stopwords.txt',"r",encoding='utf-8'))
stopword_vn_3=set(open('vietnamese-stopwords.txt',encoding='utf-8').read().split())
stopword_vn_3
# Out:
# {'a',
#  'ai',
#  'alô',
#  'amen',
#  'anh',
#  'ba',
#  'bao',
#  'bay',
#  'biến',
#  'biết',
#  'biệt',
#  'buổi',
#  'bà',
#  'bài',
#  'bác',
#  'bán',
#  'bây',
#  'bèn',
#  'béng',
#  'bên',
#  'bông',
#  'bõm',
#  'bước',
#  'bạn',
#  'bản',
#  'bảo',
#  'bất',
#  'bấy',
#  'bẩy',
#  'bập',
#  'bắt',
#  'bằng',
#  'bển',
#  'bệt',
#  'bị',
#  'bỏ',
#  'bỗng',
#  'bộ',
#  'bội',
#  'bớ',
#  'bởi',
#  'bức',
#  'cao',
#  'cha',
#  'chao',
#  'chi',
#  'chia',
#  'chiếc',
#  'cho',
#  'choa',
#  'chu',
#  'chui',
#  'chung',
#  'chuyển',
#  'chuyện',
#  'chuẩn',
#  'chà',
#  'chành',
#  'chí',
#  'chính',
#  'chót',
#  'chùn',
#  'chú',
#  'chúng',
#  'chăn',
#  'chăng',
#  'chũn',
#  'chơi',
#  'chưa',
#  'chưng',
#  'chạnh',
#  'chả',
#  'chầm',
#  'chầy',
#  'chậc',
#  'chập',
#  'chắc',
#  'chắn',
#  'chẳng',
#  'chết',
#  'chỉ',
#  'chỉn',
#  'chị',
#  'chịu',
#  'chọn',
#  'chốc',
#  'chớ',
#  'chợt',
#  'chủn',
#  'chứ',
#  'chừ',
#  'chừng',
#  'coi',
#  'con',
#  'cu',
#  'cuối',
#  'cuốn',
#  'cuộc',
#  'càng',
#  'cá',
#  'các',
#  'cách',
#  'cái',
#  'câu',
#  'cây',
#  'còn',
#  'có',
#  'cóc',
#  'cô',
#  'công',
#  'cùng',
#  'căn',
#  'cũng',
#  'cơ',
#  'cơn',
#  'cạnh',
#  'cả',
#  'cảm',
#  'cấp',
#  'cần',
#  'cầu',
#  'cật',
#  'cậu',
#  'cắt',
#  'cổ',
#  'cụ',
#  'cục',
#  'của',
#  'cứ',
#  'cực',
#  'da',
#  'do',
#  'duy',
#  'dà',
#  'dài',
#  'dành',
#  'dào',
#  'dì',
#  'dù',
#  'dùng',
#  'dĩ',
#  'dưng',
#  'dưới',
#  'dạ',
#  'dần',
#  'dầu',
#  'dẫn',
#  'dẫu',
#  'dễ',
#  'dịp',
#  'dở',
#  'dụng',
#  'dữ',
#  'em',
#  'gian',
#  'giá',
#  'giác',
#  'giảm',
#  'giống',
#  'giờ',
#  'giời',
#  'giữ',
#  'giữa',
#  'gây',
#  'gì',
#  'gần',
#  'gặp',
#  'gồm',
#  'ha',
#  'hay',
#  'hiểu',
#  'hiện',
#  'hoàn',
#  'hoặc',
#  'hãy',
#  'hèn',
#  'hình',
#  'hô',
#  'hơn',
#  'hầu',
#  'hậu',
#  'hẳn',
#  'hết',
#  'họ',
#  'hỏi',
#  'hồ',
#  'hỗ',
#  'hội',
#  'hợp',
#  'hự',
#  'khi',
#  'khiến',
#  'khoảng',
#  'khá',
#  'khác',
#  'khách',
#  'khó',
#  'khói',
#  'khô',
#  'không',
#  'khăn',
#  'khắc',
#  'khẳng',
#  'khỏi',
#  'kia',
#  'kiện',
#  'kê',
#  'kì',
#  'kìa',
#  'kể',
#  'kỳ',
#  'lai',
#  'le',
#  'liên',
#  'liệt',
#  'loại',
#  'loạt',
#  'luôn',
#  'luận',
#  'luật',
#  'luốt',
#  'là',
#  'làm',
#  'lâu',
#  'lên',
#  'lình',
#  'lí',
#  'lòng',
#  'lô',
#  'lúc',
#  'lý',
#  'lượng',
#  'lại',
#  'lấy',
#  'lần',
#  'lập',
#  'lẽ',
#  'lị',
#  'lớn',
#  'lời',
#  'lự',
#  'lực',
#  'mang',
#  'muốn',
#  'mà',
#  'mày',
#  'mình',
#  'mòi',
#  'mù',
#  'mạng',
#  'mạnh',
#  'mất',
#  'mấy',
#  'mẹ',
#  'mọi',
#  'mối',
#  'mỗi',
#  'một',
#  'mới',
#  'mở',
#  'mợ',
#  'mức',
#  'mực',
#  'nay',
#  'ngay',
#  'nghe',
#  'nghen',
#  'nghiễm',
#  'nghĩ',
#  'nghỉm',
#  'ngoài',
#  'ngoải',
#  'nguồn',
#  'ngày',
#  'ngôi',
#  'ngõ',
#  'ngăn',
#  'ngươi',
#  'người',
#  'ngắt',
#  'ngọn',
#  'ngọt',
#  'ngồi',
#  'ngộ',
#  'ngờ',
#  'nhanh',
#  'nhau',
#  'nhiên',
#  'nhiêu',
#  'nhiều',
#  'nhiệt',
#  'nhung',
#  'nhà',
#  'nhân',
#  'nhé',
#  'nhén',
#  'nhìn',
#  'nhóm',
#  'nhón',
#  'nhăng',
#  'như',
#  'nhưng',
#  'nhược',
#  'nhất',
#  'nhận',
#  'nhằm',
#  'nhỉ',
#  'nhỏ',
#  'nhớ',
#  'nhờ',
#  'nhỡ',
#  'những',
#  'nào',
#  'này',
#  'nên',
#  'nó',
#  'nóc',
#  'nói',
#  'năm',
#  'nơi',
#  'nước',
#  'nả',
#  'nấy',
#  'nặng',
#  'nếu',
#  'nền',
#  'nọ',
#  'nỗi',
#  'nớ',
#  'nở',
#  'nức',
#  'nữa',
#  'oai',
#  'oái',
#  'phi',
#  'pho',
#  'phui',
#  'phàm',
#  'phè',
#  'phía',
#  'phóc',
#  'phót',
#  'phù',
#  'phăn',
#  'phương',
#  'phải',
#  'phần',
#  'phắt',
#  'phỉ',
#  'phỏng',
#  'phốc',
#  'phụt',
#  'phứt',
#  'qua',
#  'quan',
#  'quay',
#  'qui',
#  'quy',
#  'quyết',
#  'quá',
#  'quả',
#  'quận',
#  'ra',
#  'ren',
#  'riu',
#  'riêng',
#  'riệt',
#  'rày',
#  'ráo',
#  'rén',
#  'rích',
#  'ríu',
#  'rón',
#  'rõ',
#  'rút',
#  'răng',
#  'rất',
#  'rằng',
#  'rốt',
#  'rồi',
#  'rứa',
#  'sa',
#  'sang',
#  'sao',
#  'sau',
#  'sinh',
#  'so',
#  'song',
#  'suýt',
#  'sáng',
#  'sì',
#  'sả',
#  'sất',
#  'sắp',
#  'sẻ',
#  'sẽ',
#  'số',
#  'sốt',
#  'sột',
#  'sớm',
#  'sở',
#  'sợ',
#  'sức',
#  'sử',
#  'sự',
#  'ta',
#  'tanh',
#  'tay',
#  'te',
#  'tha',
#  'than',
#  'thanh',
#  'thay',
#  'theo',
#  'thi',
#  'thiên',
#  'thiết',
#  'thiếu',
#  'thoạt',
#  'thoảng',
#  'thoắt',
#  'thuần',
#  'thuộc',
#  'thà',
#  'thành',
#  'thái',
#  'tháng',
#  'tháo',
#  'thân',
#  'thêm',
#  'thì',
#  'thình',
#  'thích',
#  'thím',
#  'thôi',
#  'thúng',
#  'thương',
#  'thường',
#  'thảo',
#  'thảy',
#  'thấp',
#  'thấy',
#  'thẩy',
#  'thậm',
#  'thật',
#  'thắng',
#  'thế',
#  'thếch',
#  'thể',
#  'thỉnh',
#  'thị',
#  'thỏm',
#  'thốc',
#  'thốt',
#  'thộc',
#  'thời',
#  'thục',
#  'thứ',
#  'thử',
#  'thửa',
#  'thực',
#  'tin',
#  'tiên',
#  'tiếp',
#  'tiện',
#  'tiệt',
#  'toà',
#  'toàn',
#  'toé',
#  'toẹt',
#  'trong',
#  'trung',
#  'tránh',
#  'tráo',
#  'trên',
#  'trình',
#  'trí',
#  'trước',
#  'trạng',
#  'trạo',
#  'trả',
#  'trếu',
#  'trển',
#  'trệt',
#  'trệu',
#  'trị',
#  'trọi',
#  'trọng',
#  'trỏng',
#  'trời',
#  'trở',
#  'trợ',
#  'trừ',
#  'trực',
#  'tuy',
#  'tuyệt',
#  'tuần',
#  'tuốt',
#  'tuồn',
#  'tuồng',
#  'tuổi',
#  'tuột',
#  'tà',
#  'tàn',
#  'tán',
#  'tâm',
#  'tê',
#  'tên',
#  'tênh',
#  'tì',
#  'tìm',
#  'tình',
#  'tính',
#  'tít',
#  'tò',
#  'tôi',
#  'tông',
#  'tù',
#  'tăm',
#  'tăng',
#  'tại',
#  'tạo',
#  'tả',
#  'tấm',
#  'tấn',
#  'tất',
#  'tần',
#  'tập',
#  'tật',
#  'tắp',
#  'tế',
#  'tề',
#  'tọt',
#  'tỏ',
#  'tốc',
#  'tối',
#  'tốt',
#  'tột',
#  'tớ',
#  'tới',
#  'tục',
#  'tức',
#  'từ',
#  'từng',
#  'tử',
#  'tự',
#  'tựu',
#  'veo',
#  'việc',
#  'vung',
#  'và',
#  'vài',
#  'vàn',
#  'vào',
#  'vâng',
#  'vèo',
#  'vì',
#  'ví',
#  'vô',
#  'vùng',
#  'văng',
#  'vượt',
#  'vạn',
#  'vả',
#  'vấn',
#  'vẫn',
#  'vậy',
#  'vẻ',
#  'về',
#  'vị',
#  'vốn',
#  'với',
#  'vở',
#  'vụt',
#  'vừa',
#  'xa',
#  'xem',
#  'xin',
#  'xiết',
#  'xon',
#  'xoành',
#  'xoét',
#  'xoạch',
#  'xoẳn',
#  'xoẹt',
#  'xuất',
#  'xuể',
#  'xuống',
#  'xón',
#  'xúi',
#  'xăm',
#  'xưa',
#  'xả',
#  'xảy',
#  'xắm',
#  'xềnh',
#  'xệch',
#  'xệp',
#  'xử',
#  'xửa',
#  'yêu',
#  'à',
#  'ào',
#  'á',
#  'ái',
#  'áng',
#  'âu',
#  'ít',
#  'ô',
#  'ôi',
#  'ông',
#  'úi',
#  'ý',
#  'ăn',
#  'đang',
#  'đi',
#  'điều',
#  'điểm',
#  'đành',
#  'đán',
#  'đáng',
#  'đánh',
#  'đáo',
#  'đâu',
#  'đây',
#  'đã',
#  'đó',
#  'đùng',
#  'đúng',
#  'đơn',
#  'đưa',
#  'được',
#  'đạch',
#  'đại',
#  'đạt',
#  'đảm',
#  'đất',
#  'đấy',
#  'đầu',
#  'đầy',
#  'đặc',
#  'đặt',
#  'đến',
#  'đề',
#  'đều',
#  'để',
#  'địa',
#  'định',
#  'đối',
#  'đồ',
#  'đồng',
#  'đổi',
#  'đủ',
#  'ơ',
#  'ơi',
#  'ơn',
#  'ư',
#  'ạ',
#  'ấy',
#  'ầu',
#  'ắt',
#  'ối',
#  'ồ',
#  'ổng',
#  'ớ',
#  'ờ',
#  'ở',
#  'ủa',
#  'ứ',
#  'ừ',
#  'ử'}

# %%
# Đọc file ngon_tu_quang_cao.txt => đưa nội dung vào biến text
text=pd.read_csv('ngon_tu_quang_cao.txt',sep='\n').to_string()
text
# Out:
# '                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           NGÔN TỪ TRONG QUẢNG CÁO\n0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Giới thiệu\n1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Việt Nam đang từng bước hội nhập vào nền kinh tế thế giới, do đó hoạt động quảng cáo, tiếp thị ngày càng phát triển với tốc độ rất nhanh và đã góp phần làm đổi thay từng bước diện mạo của nền kinh tế và văn hóa Việt Nam.\n2                                                                                                                                                                                                                                                                                                                                                   ...

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div class="output_subarea output_text output_result"><pre>'\ufeffNGÔN TỪ TRONG QUẢNG CÁO\nGiới thiệu\nViệt Nam đang từng bước hội nhập vào nền kinh tế thế giới, do đó hoạt động quảng cáo, tiếp thị ngày càng phát triển với tốc độ rất nhanh và đã góp phần làm đổi thay từng bước diện mạo của nền kinh tế và văn hóa Việt Nam.\nHiện nay, đâu đâu, khi ở nhà hay ra ngoài đường, trong rạp hát, rạp chiếu phim, bến xe, ga tàu, trường học… đều đập vào mắt mọi người những hình ảnh và thông tin quảng cáo đủ loại và đủ màu sắc của nhiều mặt hàng sản phẩm. Bên cạnh những yếu tố hình ảnh, màu sắc, âm thanh, thì yếu tố ngôn từ cũng cần được quan tâm chú ý nhiều hơn và việc sử dụng ngôn từ như thế nào cho phù hợp với tính dân tộc Việt Nam, có tính hấp dẫn, hiệu quả đã trở thành một nghệ thuật thực sự. Thế nhưng, công tác quản lý dịch vụ này vẫn còn rất nhiều điều bất cập, các vấn đề thiết yếu về ngôn ngữ, văn hóa và pháp lý chưa phù hợp với văn hóa dân tộc Việt Nam. Chính vì vậy, hơn lúc nào hết, việc nghiên cứu ngôn ngữ quảng cáo là rất cần thiết trong các phương tiện quảng cáo hiện nay.\nVậy ngôn từ trong quảng cáo là gì?\nQuảng cáo chính là một trong những cầu nối quan trọng giữa nhà sản xuất và người tiêu dùng. Thông qua những chất liệu khác nhau như hình ảnh, màu sắc, âm thanh, ngôn từ… của quảng cáo, nhà sản xuất giới thiệu sản phẩm của mình đến với khác hàng. Ở đây, “ngôn từ quảng cáo”, hiểu theo nghĩa cụ thể, đó là tất cả các ký tự chữ viết có nội dung được thể hiện trên một mẩu quảng cáo theo một kịch bản hoặc một chiến lược quảng cáo nhất định, nhằm đạt đến một hay nhiều mục đích do nhà quảng cáo đề ra.\nĐặc điểm của nghệ thuật ngôn từ trong quảng cáo\n   Đặc điểm của ngôn từ quảng cáo là ngắn gọn, dễ nhớ, tạo ấn tượng và phải phù hợp với kết cấu ngôn ngữ. Với tiếng Việt, ngoài việc tận dụng những từ đồng âm, đồng nghĩa, thanh điệu, vần… còn xét về tính ẩn dụ, thậm xưng, nhân hóa… Nó không nhất thiết phải được cấu tạo thành câu hoàn chỉnh và có nhiều câu như đối với ngôn từ của một văn bản hành chính hay khoa học, mà thường chỉ là những cụm từ ngắn gọn, có nội dung cô đọng, hàm súc và đôi khi được thẩm mỹ hóa bằng các biện pháp nghệ thuật và đặc biệt phải phù hợp văn hóa Việt Nam ví dụ như “Tết làm điều hay, vận may nhân khắp” trong quảng cáo sản phẩm “Omo”.\n Bên cạnh ngôn từ, quảng cáo còn bao gồm cả hình ảnh, âm thanh, màu sắc…, ngôn từ dù nhỏ nhất sẽ là chìa khóa quan trọng để giải mã cho những ẩn ý nằm đằng sau các hình ảnh. Trong quảng cáo, ẩn dụ ngôn từ được sử dụng triệt để, đặc biệt là trong xu hướng quảng cáo hiện nay. Vì qua ẩn dụ người ta khám phá ra một loạt hàm ngôn. Việc sử dụng ngôn từ trong quảng cáo không đơn giản chỉ là đưa vào những từ ngữ dựa trên sự vận dụng các thủ pháp và định đề một cách tự nhiên, máy móc. Mà thực tế, nó là một nghệ thuật dùng từ có sự dung hòa, thõa mãn rất nhiều yếu tố tác động và chi phối khác nhau như sản phẩm và nội dung của sản phẩm, thị trường, thị hiếu tiêu dùng, đối tượng khách hàng, pháp luật, văn hóa, mức sống… Thông qua ngôn ngữ và các phương tiện chuyển tải, người quảng cáo sẽ sáng tạo nên những ngôn từ tốt nhất, hiệu quả nhất cho mẩu quảng cáo. Theo đó, chúng không chỉ góp phần cung cấp và chuyển tải thông tin sản phẩm đến người xem, mà trên cơ sở đó, còn phải tạo được sự chú ý, sự hấp dẫn và thuyết phục cao nhất đối với người xem bằng tính hài hước, xác thực, độc đáo, thẩm mỹ…\nNhư vậy, qua việc phân tích ngôn từ trong những mẫu quảng cáo trên, chúng ta thấy được phần nào những cách thức sử dụng, vai trò và ý nghĩa của ngôn từ trong việc quảng cáo hiện nay, cũng như các đặc điểm, xu hướng của việc sử dụng ngôn từ trong quảng cáo. Ngôn ngữ cũng có những quy luật phát triển riêng. Bản thân ngôn ngữ trong quá trình tồn tại luôn có những biến thể, cách sử dụng ngôn ngữ mới. Tuy nhiên, những biến thể đó trong ngôn ngữ cộng đồng cần được đặt trong phạm vi văn hóa dân tộc truyền thống. Ngôn từ là một bộ phận, một thành tố rất quan trọng và gần như không thể thiếu được trong quảng cáo. Nó đóng vai trò to lớn có tính quyết định đến sự hiệu quả và thành công của một chương trình quảng cáo. Việc sáng tạo ngôn từ quảng cáo vì vậy trở nên vô cùng quan trọng và được xem như một hoạt động nghệ thuật thực sự. Đã đến lúc chúng ta cần có những chuẩn mực trong văn hóa sử dụng ngôn từ. Chỉ có như vậy, mới gìn giữ được sự trong sáng của tiếng Việt, gìn giữ được bản sắc văn hóa của dân tộc. Suy cho cùng, những sản phẩm quảng cáo không chỉ là để giới thiệu sản phẩm đến người tiêu dùng mà thông qua đó chuyển tải ý nghĩa, thông điệp và đôi khi chuyên chở cả một giá trị văn hóa của một quốc gia.\nTheo: www...'</pre></div>
#
# </details>

# %%
# Bổ sung thêm một số từ không quan trọng vào stopwords

# %%
# Vẽ wordclouds
wordcloud=wordcloud = WordCloud(background_color ='white',stopwords = stopword_vn_3).generate(text)
plt.figure(figsize=(10,12))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div class="output_subarea output_png"><img src="data:image/png;base64,...
# "></div>
#
# </details>

# %%
import numpy as np
from PIL import Image

# %%
# Chọn hình làm wc_mask phù hợp
wc_mark=np.array(Image.open('ad_s.png'))

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div class="output_subarea output_png"><img src="data:image/png;base64,...
# "></div>
#
# </details>

# %%
# Vẽ wordclouds với wc_mask
wordcloud=wordcloud = WordCloud(background_color ='white',mask=wc_mark,stopwords = stopword_vn_3).generate(text)
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div class="output_subarea output_png"><img src="data:image/png;base64,...
# "></div>
#
# </details>
