# %%
# Tạo trang R trên colab: https://colab.research.google.com/notebook#create=true&language=r
a <- 5
b <- 7
c <- a + b

# %%
fruit <- c("a",'b','c')

# %%
print(fruit)
# Out:
# [1] "a" "b" "c"

# %%
print(c)
# Out:
# [1] 12

# %%
M=matrix(c(1:12), nrow=4, ncol=3, byrow=TRUE)
print(M)
# Out:
#      [,1] [,2] [,3]
# [1,]    1    2    3
# [2,]    4    5    6
# [3,]    7    8    9
# [4,]   10   11   12

# %%
N=matrix(c(1:12), nrow=4, ncol=3, byrow=FALSE)
print(N)
# Out:
#      [,1] [,2] [,3]
# [1,]    1    5    9
# [2,]    2    6   10
# [3,]    3    7   11
# [4,]    4    8   12

# %%
N=matrix(c(1:12), nrow=4, byrow=TRUE)

# %%
rownames=c("row1", "row2", "row3", "row4")
colnames=c("col1", "col2", "col3")

# %%
P=matrix(c(1:12), nrow=4, byrow=TRUE, dimnames=list(rownames, colnames))
print(P)
# Out:
#      col1 col2 col3
# row1    1    2    3
# row2    4    5    6
# row3    7    8    9
# row4   10   11   12

# %%
print(P[1,3])
# Out:
# [1] 3

# %%
print(P[4,2])
# Out:
# [1] 11

# %%
print(P[2,])
# Out:
# col1 col2 col3
#    4    5    6

# %%
print(P[,3])
# Out:
# row1 row2 row3 row4
#    3    6    9   12

# %%
M1=matrix(c(3:14), nrow=2, byrow=TRUE)
M2=matrix(c(1:12), nrow=4, byrow=TRUE)

# %%
print(M1)
# Out:
#      [,1] [,2] [,3] [,4] [,5] [,6] [,7]
# [1,]    3    4    5    6    7    8    9
# [2,]   10   11   12   13   14   15   16

# %%
print(M2)
# Out:
#      [,1] [,2] [,3] [,4]
# [1,]    1    2    3    4
# [2,]    5    6    7    8
# [3,]    9   10   11   12
# [4,]   13   14   15   16

# %%
result_add=M1+M2
cat("Result of addition","\n")
print(result_add)
# Out:
# Result of addition
#      [,1] [,2] [,3] [,4] [,5] [,6] [,7]
# [1,]    4    6    8   10   12   14   16
# [2,]   18   20   22   24   26   28   30

# %%
mat1=matrix(c(3:18), ncol=4, byrow=TRUE)
mat2=matrix(c(1:16), nrow=4, byrow=TRUE)

# %%
mat3=mat1%*%mat2

# %%
print(mat3)
# Out:
#      [,1] [,2] [,3] [,4]
# [1,]  146  164  182  200
# [2,]  258  292  326  360
# [3,]  370  420  470  520
# [4,]  482  548  614  680

# %%
vec=c(1:3)
mat=matrix(c(1:9), ncol=3)
print(vec)
print(mat)
# Out:
# [1] 1 2 3
#      [,1] [,2] [,3]
# [1,]    1    4    7
# [2,]    2    5    8
# [3,]    3    6    9

# %%
vec_new=mat%*%vec
print(vec_new)
# Out:
#      [,1]
# [1,]   30
# [2,]   36
# [3,]   42

# %%
v1=c(1:6)
v2=c(7:15)

# %%
array1=array(v1, dim=c(3,2,2))
print(array1)
# Out:
# , , 1
#
#      [,1] [,2]
# [1,]    1    4
# [2,]    2    5
# [3,]    3    6
#
# , , 2
#
#      [,1] [,2]
# [1,]    1    4
# [2,]    2    5
# [3,]    3    6

# %%
array2=array(c(v1,v2), dim=c(3,4,2))
print(array2)
# Out:
# , , 1
#
#      [,1] [,2] [,3] [,4]
# [1,]    1    4    7   10
# [2,]    2    5    8   11
# [3,]    3    6    9   12
#
# , , 2
#
#      [,1] [,2] [,3] [,4]
# [1,]   13    1    4    7
# [2,]   14    2    5    8
# [3,]   15    3    6    9

# %%
row_names=c("row1", "row2", "row3")
col_names=c("col1", "col2", "col3", "col4")
mat_names=c("matrix1","matrix2")
array3=array(c(v1,v2), dim=c(3,4,2), dimnames=list(row_names, col_names, mat_names))
print(array3)
# Out:
# , , matrix1
#
#      col1 col2 col3 col4
# row1    1    4    7   10
# row2    2    5    8   11
# row3    3    6    9   12
#
# , , matrix2
#
#      col1 col2 col3 col4
# row1   13    1    4    7
# row2   14    2    5    8
# row3   15    3    6    9

# %%
print(array3[3,2,1])
# Out:
# [1] 6

# %%
print(array3[1,,2])
# Out:
# col1 col2 col3 col4
#   13    1    4    7

# %%
print(array3[,,2])
# Out:
#      col1 col2 col3 col4
# row1   13    1    4    7
# row2   14    2    5    8
# row3   15    3    6    9

# %%
print(array3[,3,1])
# Out:
# row1 row2 row3
#    7    8    9

# %%
print(apply(array3, c(1),sum))
# Out:
# row1 row2 row3
#   47   55   63

# %%
print(apply(array3, c(2),min))
# Out:
# col1 col2 col3 col4
#    1    1    4    7

# %%
print(apply(array3, c(3),mean))
# Out:
# matrix1 matrix2
#    6.50    7.25

# %%
list_data=list("hello", "R", 12, 25.5, c(21,32, 11), TRUE)
print(list_data)
# Out:
# [[1]]
# [1] "hello"
#
# [[2]]
# [1] "R"
#
# [[3]]
# [1] 12
#
# [[4]]
# [1] 25.5
#
# [[5]]
# [1] 21 32 11
#
# [[6]]
# [1] TRUE

# %%
list_1=list(c("Red", "Green", "Yello"), matrix(c(1:8),nrow=2), list("green", TRUE, 12.5), TRUE)

# %%
names(list_1)=c("Traffic Light", "A_Matrix", "An Inner List", "Pass")

# %%
print(list_1)
# Out:
# $`Traffic Light`
# [1] "Red"   "Green" "Yello"
#
# $A_Matrix
#      [,1] [,2] [,3] [,4]
# [1,]    1    3    5    7
# [2,]    2    4    6    8
#
# $`An Inner List`
# $`An Inner List`[[1]]
# [1] "green"
#
# $`An Inner List`[[2]]
# [1] TRUE
#
# $`An Inner List`[[3]]
# [1] 12.5
#
#
# $Pass
# [1] TRUE

# %%
print(list_1[1])
# Out:
# $`Traffic Light`
# [1] "Red"   "Green" "Yello"

# %%
print(list_1$A_Matrix)
# Out:
#      [,1] [,2] [,3] [,4]
# [1,]    1    3    5    7
# [2,]    2    4    6    8

# %%
list_1[length(list_1)+1]="New element"

# %%
print(list_1[length(list_1)])
# Out:
# [[1]]
# [1] "New element"

# %%
list_1[length(list_1)]=NULL

# %%
list_1
# Out:
# $`Traffic Light`
# [1] "Red"   "Green" "Yello"
#
# $A_Matrix
#      [,1] [,2] [,3] [,4]
# [1,]    1    3    5    7
# [2,]    2    4    6    8
#
# $`An Inner List`
# $`An Inner List`[[1]]
# [1] "green"
#
# $`An Inner List`[[2]]
# [1] TRUE
#
# $`An Inner List`[[3]]
# [1] 12.5
#
#
# $Pass
# [1] TRUE

# %%
list_1[3]=TRUE

# %%
print(list_1[3])
# Out:
# $`An Inner List`
# [1] TRUE

# %%
list1=list(1, TRUE, c("Red", "Green", "Yellow"))
list2=list(TRUE, "hello", 12.5)

# %%
merged.list=c(list1, list2)

# %%
print(merged.list)
# Out:
# [[1]]
# [1] 1
#
# [[2]]
# [1] TRUE
#
# [[3]]
# [1] "Red"    "Green"  "Yellow"
#
# [[4]]
# [1] TRUE
#
# [[5]]
# [1] "hello"
#
# [[6]]
# [1] 12.5

# %%
list1=list(1:5)
list2=list(6:10)
v1=unlist(list1)
v2=unlist(list2)

# %%
print(v1)
print(v2)
# Out:
# [1] 1 2 3 4 5
# [1]  6  7  8  9 10

# %%
students_1=data.frame("name"=c('Helen', 'Jolie', 'Kiwi', 'John', 'Mark', 'Tom'), "age"=c(17,16,17,18,19,16), "mark"= c(9,9,8,7.5,7.5,8), stringsAsFactors=FALSE)
print(students_1)
# Out:
#    name age mark
# 1 Helen  17  9.0
# 2 Jolie  16  9.0
# 3  Kiwi  17  8.0
# 4  John  18  7.5
# 5  Mark  19  7.5
# 6   Tom  16  8.0

# %%
"name"=c('Helen', 'Jolie', 'Kiwi', 'John', 'Mark', 'Tom')
"age"=c(17,16,17,18,19,16)
"mark"= c(9,9,8,7.5,7.5,8)
students=data.frame(name, age, mark, stringsAsFactors=FALSE)

# %%
print(students)
# Out:
#    name age mark
# 1 Helen  17  9.0
# 2 Jolie  16  9.0
# 3  Kiwi  17  8.0
# 4  John  18  7.5
# 5  Mark  19  7.5
# 6   Tom  16  8.0

# %%
str(students)
# Out:
# 'data.frame':	6 obs. of  3 variables:
#  $ name: chr  "Helen" "Jolie" "Kiwi" "John" ...
#  $ age : num  17 16 17 18 19 16
#  $ mark: num  9 9 8 7.5 7.5 8

# %%
print(summary(students))
# Out:
#      name                age             mark
#  Length:6           Min.   :16.00   Min.   :7.500
#  Class :character   1st Qu.:16.25   1st Qu.:7.625
#  Mode  :character   Median :17.00   Median :8.000
#                     Mean   :17.17   Mean   :8.167
#                     3rd Qu.:17.75   3rd Qu.:8.750
#                     Max.   :19.00   Max.   :9.000

# %%
print(students$mark)
# Out:
# [1] 9.0 9.0 8.0 7.5 7.5 8.0

# %%
print(data.frame(students$age))
# Out:
#   students.age
# 1           17
# 2           16
# 3           17
# 4           18
# 5           19
# 6           16

# %%
print(students[1:2,])
# Out:
#    name age mark
# 1 Helen  17    9
# 2 Jolie  16    9

# %%
print(students[c(3,5), c(1,2)])
# Out:
#   name age
# 3 Kiwi  17
# 5 Mark  19

# %%
students$class=c("k256_S7N","k256_C7N", "k256_S7N","k256_S24", "k256_S24", "k256_C7N")
students
# Out:
#   name  age mark class
# 1 Helen 17  9.0  k256_S7N
# 2 Jolie 16  9.0  k256_C7N
# 3 Kiwi  17  8.0  k256_S7N
# 4 John  18  7.5  k256_S24
# 5 Mark  19  7.5  k256_S24
# 6 Tom   16  8.0  k256_C7N

# %%
df_POB=data.frame("POB"=c("UK","US","EU","UK", "US", "EU"))
students=cbind(students, df_POB)

# %%
students
# Out:
#   name  age mark class    POB
# 1 Helen 17  9.0  k256_S7N UK
# 2 Jolie 16  9.0  k256_C7N US
# 3 Kiwi  17  8.0  k256_S7N EU
# 4 John  18  7.5  k256_S24 UK
# 5 Mark  19  7.5  k256_S24 US
# 6 Tom   16  8.0  k256_C7N EU

# %%
new_students=data.frame("name"=c('Sunny','Lucy'),"age"=c(17,18),"mark"=c(8,9),"class"=c("k256_C7N","k256_S24"),'POB'=c("EU","UK"),stringsAsFactors=FALSE)

# %%
print(new_students)
# Out:
#    name age mark    class POB
# 1 Sunny  17    8 k256_C7N  EU
# 2  Lucy  18    9 k256_S24  UK

# %%
students=rbind(students, new_students)

# %%
students
# Out:
#   name  age mark class    POB
# 1 Helen 17  9.0  k256_S7N UK
# 2 Jolie 16  9.0  k256_C7N US
# 3 Kiwi  17  8.0  k256_S7N EU
# 4 John  18  7.5  k256_S24 UK
# 5 Mark  19  7.5  k256_S24 US
# 6 Tom   16  8.0  k256_C7N EU
# 7 Sunny 17  8.0  k256_C7N EU
# 8 Lucy  18  9.0  k256_S24 UK

# %%
names(students)[names(students)=="POB"]="Place_of_birth"
head(students)
# Out:
#   name  age mark class    Place_of_birth
# 1 Helen 17  9.0  k256_S7N UK
# 2 Jolie 16  9.0  k256_C7N US
# 3 Kiwi  17  8.0  k256_S7N EU
# 4 John  18  7.5  k256_S24 UK
# 5 Mark  19  7.5  k256_S24 US
# 6 Tom   16  8.0  k256_C7N EU

# %%
install.packages('tidyverse')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(tidyverse)
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.6     ✔ dplyr   1.0.8
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
system("ls", TRUE)
# Out:
# [1] "sample_data"

# %%
#https://drive.google.com/file/d/1dFDda7yxSfENn9i-Oe9IMJ6VUTFHpZLK/view?usp=sharing
system('gdown --id 1dFDda7yxSfENn9i-Oe9IMJ6VUTFHpZLK')

# %%
pokemon=read.csv('pokemon.csv')

# %%
head(pokemon)
# Out:
#   X. Name                  Type.1 Type.2 Total HP Attack Defense Sp..Atk
# 1 1  Bulbasaur             Grass  Poison 318   45  49     49      65
# 2 2  Ivysaur               Grass  Poison 405   60  62     63      80
# 3 3  Venusaur              Grass  Poison 525   80  82     83     100
# 4 3  VenusaurMega Venusaur Grass  Poison 625   80 100    123     122
# 5 4  Charmander            Fire          309   39  52     43      60
# 6 5  Charmeleon            Fire          405   58  64     58      80
#   Sp..Def Speed Generation Legendary
# 1  65     45    1          False
# 2  80     60    1          False
# 3 100     80    1          False
# 4 120     80    1          False
# 5  50     65    1          False
# 6  65     80    1          False

# %%
pokemon_sub=select(pokemon, c(2,5,7,8))

# %%
head(pokemon_sub)
# Out:
#   Name                  Total Attack Defense
# 1 Bulbasaur             318    49     49
# 2 Ivysaur               405    62     63
# 3 Venusaur              525    82     83
# 4 VenusaurMega Venusaur 625   100    123
# 5 Charmander            309    52     43
# 6 Charmeleon            405    64     58

# %%
pokemon_sub=pokemon %>% select(Name, Total, Attack, Defense)
head(pokemon_sub)
# Out:
#   Name                  Total Attack Defense
# 1 Bulbasaur             318    49     49
# 2 Ivysaur               405    62     63
# 3 Venusaur              525    82     83
# 4 VenusaurMega Venusaur 625   100    123
# 5 Charmander            309    52     43
# 6 Charmeleon            405    64     58

# %%
pokemon_numbers=select_if(pokemon, is_numeric)
# Out:
# Warning message:
# “Deprecated”
# Warning message:
# “Deprecated”
# Warning message:
# “Deprecated”
# Warning message:
# “Deprecated”
# Warning message:
# “Deprecated”
# Warning message:
# “Deprecated”
# Warning message:
# “Deprecated”
# Warning message:
# “Deprecated”
# Warning message:
# “Deprecated”
# Warning message:
# “Deprecated”
# Warning message:
# “Deprecated”
# Warning message:
# “Deprecated”
# Warning message:
# “Deprecated”

# %%
head(pokemon_numbers)
# Out:
#   X. Total HP Attack Defense Sp..Atk Sp..Def Speed Generation
# 1 1  318   45  49     49      65      65     45    1
# 2 2  405   60  62     63      80      80     60    1
# 3 3  525   80  82     83     100     100     80    1
# 4 3  625   80 100    123     122     120     80    1
# 5 4  309   39  52     43      60      50     65    1
# 6 5  405   58  64     58      80      65     80    1

# %%
pokemon_500_600=filter(pokemon_sub, Total >=500, Total <=600)
head(pokemon_500_600)
# Out:
#   Name                Total Attack Defense
# 1 Venusaur            525    82     83
# 2 Charizard           534    84     78
# 3 Blastoise           530    83    100
# 4 PidgeotMega Pidgeot 579    80     80
# 5 Nidoqueen           505    92     87
# 6 Nidoking            505   102     77

# %%
pokemon_A=filter(pokemon, Attack>Defense)

# %%
pokemon_attack_defense=filter(pokemon_sub, Attack>Defense)
head(pokemon_attack_defense)
# Out:
#   Name                      Total Attack Defense
# 1 Charmander                309    52     43
# 2 Charmeleon                405    64     58
# 3 Charizard                 534    84     78
# 4 CharizardMega Charizard X 634   130    111
# 5 CharizardMega Charizard Y 634   104     78
# 6 Weedle                    195    35     30

# %%
pokemon_sub=mutate(pokemon_sub, Compare= ifelse(Attack>Defense,1,0))
head(pokemon_sub)
# Out:
#   Name                  Total Attack Defense Compare
# 1 Bulbasaur             318    49     49     0
# 2 Ivysaur               405    62     63     0
# 3 Venusaur              525    82     83     0
# 4 VenusaurMega Venusaur 625   100    123     0
# 5 Charmander            309    52     43     1
# 6 Charmeleon            405    64     58     1

# %%
head(arrange(pokemon_sub, Total))
# Out:
#   Name      Total Attack Defense Compare
# 1 Sunkern   180   30     30      0
# 2 Azurill   190   20     40      0
# 3 Kricketot 194   25     41      0
# 4 Caterpie  195   30     35      0
# 5 Weedle    195   35     30      1
# 6 Wurmple   195   45     35      1

# %%
head(arrange(pokemon_sub, desc(Total)))
# Out:
#   Name                  Total Attack Defense Compare
# 1 MewtwoMega Mewtwo X   780   190    100     1
# 2 MewtwoMega Mewtwo Y   780   150     70     1
# 3 RayquazaMega Rayquaza 780   180    100     1
# 4 KyogrePrimal Kyogre   770   150     90     1
# 5 GroudonPrimal Groudon 770   180    160     1
# 6 Arceus                720   120    120     0

# %%
head(arrange(pokemon_sub, desc(Total), desc(Attack)))
# Out:
#   Name                  Total Attack Defense Compare
# 1 MewtwoMega Mewtwo X   780   190    100     1
# 2 RayquazaMega Rayquaza 780   180    100     1
# 3 MewtwoMega Mewtwo Y   780   150     70     1
# 4 GroudonPrimal Groudon 770   180    160     1
# 5 KyogrePrimal Kyogre   770   150     90     1
# 6 Arceus                720   120    120     0

# %%
group=group_by(pokemon, Type.1)
sum_data=summarize(group, count =n(), mean.Attack=mean(Attack, na.rm=T), median.Attack=median(Attack, na.rm=T), mean.Defense=mean(Attack, na.rm=T), median.Defense=median(Attack, na.rm=T))

# %%
sum_data
# Out:
#    Type.1   count mean.Attack median.Attack mean.Defense median.Defense
# 1  Bug       69    70.97101    65.0          70.97101     65.0
# 2  Dark      31    88.38710    88.0          88.38710     88.0
# 3  Dragon    32   112.12500   113.5         112.12500    113.5
# 4  Electric  44    69.09091    65.0          69.09091     65.0
# 5  Fairy     17    61.52941    52.0          61.52941     52.0
# 6  Fighting  27    96.77778   100.0          96.77778    100.0
# 7  Fire      52    84.76923    84.5          84.76923     84.5
# 8  Flying     4    78.75000    85.0          78.75000     85.0
# 9  Ghost     32    73.78125    66.0          73.78125     66.0
# 10 Grass     70    73.21429    70.0          73.21429     70.0
# 11 Ground    32    95.75000    85.0          95.75000     85.0
# 12 Ice       24    72.75000    67.0          72.75000     67.0
# 13 Normal    98    73.46939    70.5          73.46939     70.5
# 14 Poison    28    74.67857    74.0          74.67857     74.0
# ...

# %%
count(pokemon, Type.1)
# Out:
#    Type.1   n
# 1  Bug       69
# 2  Dark      31
# 3  Dragon    32
# 4  Electric  44
# 5  Fairy     17
# 6  Fighting  27
# 7  Fire      52
# 8  Flying     4
# 9  Ghost     32
# 10 Grass     70
# 11 Ground    32
# 12 Ice       24
# 13 Normal    98
# 14 Poison    28
# 15 Psychic   57
# 16 Rock      44
# 17 Steel     27
# 18 Water    112

# %%
pokemon %>% sample_n(5)
# Out:
#   X.  Name    Type.1   Type.2 Total HP  Attack Defense Sp..Atk Sp..Def Speed
# 1 145 Zapdos  Electric Flying 580    90  90     85     125     90      100
# 2 372 Shelgon Dragon          420    65  95    100      60     50       50
# 3  14 Kakuna  Bug      Poison 205    45  25     50      25     25       35
# 4 667 Litleo  Fire     Normal 369    62  50     58      73     54       72
# 5 717 Yveltal Dark     Flying 680   126 131     95     131     98       99
#   Generation Legendary
# 1 1          True
# 2 3          False
# 3 1          False
# 4 6          False
# 5 6          True

# %%
sub_5_per=pokemon %>%sample_frac(0.05)
dim(sub_5_per)
# Out:
# [1] 40 13
