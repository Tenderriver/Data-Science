# %% [markdown]
# ## Chapter 7 - Exercise 1: Tips

# %% [markdown]
# #### Cho dữ liệu tips có sẵn trong seaborn library. Hãy vẽ những biểu đồ theo yêu cầu, và đối chiếu với kết quả cho trước:

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# Load dữ liệu tips có sẵn trong seaborn library
#total_bill: Total bill (cost of the meal), including tax, in US dollars
#tip: Tip (gratuity) in US dollars
#sex: Sex of person paying for the meal (0=male, 1=female)
#smoker: Smoker in party? (0=No, 1=Yes)
#day: 3=Thur, 4=Fri, 5=Sat, 6=Sun
#time: 0=Day, 1=Night
#size: Size of the party
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <pre>&lt;class 'pandas.core.frame.DataFrame'&gt;
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB
# </pre>
#
#  <div class="output_subarea output_html rendered_html output_result"><div>
# <style scoped="">
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>total_bill</th>
#       <th>tip</th>
#       <th>sex</th>
#       <th>smoker</th>
#       <th>day</th>
#       <th>time</th>
#       <th>size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>234</th>
#       <td>15.53</td>
#       <td>3.00</td>
#       <td>Male</td>
#       <td>Yes</td>
#       <td>Sat</td>
#       <td>Dinner</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>235</th>
#       <td>10.07</td>
#       <td>1.25</td>
#       <td>Male</td>
#       <td>No</td>
#       <td>Sat</td>
#       <td>Dinner</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>236</th>
#       <td>12.60</td>
#       <td>1.00</td>
#       <td>Male</td>
#       <td>Yes</td>
#       <td>Sat</td>
#       <td>Dinner</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>237</th>
#       <td>32.83</td>
#       <td>1.17</td>
#       <td>Male</td>
#       <td>Yes</td>
#       <td>Sat</td>
#       <td>Dinner</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>238</th>
#       <td>35.83</td>
#       <td>4.67</td>
#       <td>Female</td>
#       <td>No</td>
#       <td>Sat</td>
#       <td>Dinner</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>239</th>
#       <td>29.03</td>
#       <td>5.92</td>
#       <td>Male</td>
#       <td>No</td>
#       <td>Sat</td>
#       <td>Dinner</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>240</th>
#       <td>27.18</td>
#       <td>2.00</td>
#       <td>Female</td>
#       <td>Yes</td>
#       <td>Sat</td>
#       <td>Dinner</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>241</th>
#       <td>22.67</td>
#       <td>2.00</td>
#       <td>Male</td>
#       <td>Yes</td>
#       <td>Sat</td>
#       <td>Dinner</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>242</th>
#       <td>17.82</td>
#       <td>1.75</td>
#       <td>Male</td>
#       <td>No</td>
#       <td>Sat</td>
#       <td>Dinner</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>243</th>
#       <td>18.78</td>
#       <td>3.00</td>
#       <td>Female</td>
#       <td>No</td>
#       <td>Thur</td>
#       <td>Dinner</td>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# </details>

# %%
# Câu 1: Vẽ violinplot cho cho cột total_bill
# Bạn nhận xét gì về biểu đồ vừa tạo
sns.violinplot(data=tips,x='total_bill')
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div class="output_subarea output_png"><img src="data:image/png;base64,...
# "></div>
#
# </details>

# %%
# Câu 2: Vẽ swarmplot cho cột total_bill theo sex
# Bạn nhận xét gì về biểu đồ vừa tạo
plt.figure(figsize=(8,6))
sns.swarmplot(data=tips,x='total_bill',y='sex')
plt.show()

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div class="output_subarea output_png"><img src="data:image/png;base64,...
# "></div>
#
# </details>

# %%
# Câu 3: Vẽ boxplot cho cột total_bill
# Bạn nhận xét gì về biểu đồ vừa tạo
sns.boxplot(x='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div class="output_subarea output_png"><img src="data:image/png;base64,...
# "></div>
#
# </details>

# %%
tips['time'].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Dinner', 'Lunch']

# %%
# Câu 4: Tạo FacetGrid của total_bill theo 'time' và chỉ định thứ tự của các cột bằng col_order
# Bạn nhận xét gì về biểu đồ vừa tạo
g2=sns.FacetGrid(tips,col='time',col_order=['Dinner', 'Lunch'],aspect=2)
g2.map(sns.boxplot,'total_bill',order=None)
plt.show()
plt.clf()

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div class="output_subarea output_png"><img src="data:image/png;base64,...
# "></div>
#
# </details>

# %%
# Câu 5: Tạo catplot chứa point plot của giá trị 'total_bill' thay đổi theo size và tách dòng theo ‘time’
# Bạn nhận xét gì về biểu đồ vừa tạo
sns.catplot(data=tips,y='total_bill',x='size',kind='point',row='time')
plt.show()

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div class="output_subarea output_png"><img src="data:image/png;base64,...
# "></div>
#
# </details>

# %%
# Câu 6: Tạo PairGrid với scatter plot thể hiện liên quan giữa "total_bill" và "tip" 
# Bạn nhận xét gì về biểu đồ vừa tạo
g=sns.PairGrid(tips,vars=["total_bill","tip"])
g2=g.map(plt.scatter)
plt.show()

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div class="output_subarea output_png"><img src="data:image/png;base64,...
# "></div>
#
# </details>

# %%
# Câu 7: Tạo Pairplot với scatter plot thể hiện liên quan giữa "total_bill" và "tip", sử dụng palette color = 'day' 
# Bạn nhận xét gì về biểu đồ vừa tạo
sns.pairplot(data=tips,vars=["total_bill","tip"],kind='scatter',hue='day',palette='husl')
plt.show()

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div class="output_subarea output_png"><img src="data:image/png;base64,...
# "></div>
#
# </details>
