# %%
# Tạo trang R trên colab: https://colab.research.google.com/notebook#create=true&language=r
a <- 5
b <- 7
c <- a + b

# %%
fruit <- c("a",'b','c')

# %%
print(fruit)
# Out:
# [1] "a" "b" "c"

# %%
print(c)
# Out:
# [1] 12

# %%
#https://drive.google.com/file/d/1ezOctUhyHkC54MnEB1ACSYRxfpbxBcjI/view?usp=sharing

# %%
library('corrplot')
library('ggplot2')

# %%
mydata=read.csv("binary.csv")
print(head(mydata))
print(tail(mydata))
print(summary(mydata))

# %%
library(Amelia)
missmap(mydata, main="Missing values vs observed")
print(table(mydata$admit))
