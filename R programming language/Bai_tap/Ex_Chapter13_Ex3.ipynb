# %%
# Tạo trang R trên colab: https://colab.research.google.com/notebook#create=true&language=r
a <- 5
b <- 7
c <- a + b

# %%
fruit <- c("a",'b','c')

# %%
print(fruit)
# Out:
# [1] "a" "b" "c"

# %%
print(c)
# Out:
# [1] 12

# %% [markdown]
# **Ex3: Students**

# %%
install.packages("xlsx")
library("xlsx")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘rJava’, ‘xlsxjars’

# %%
#https://docs.google.com/spreadsheets/d/1oUJzdq4E16vxpQyPYdY8T4rAKVmnedQz/edit?usp=sharing&ouid=100667830146032102250&rtpof=true&sd=true
system('gdown --id 1oUJzdq4E16vxpQyPYdY8T4rAKVmnedQz')

# %%
df <- read.xlsx("students.xls", sheetName ="Full")
print("Content of file:")
head(df)
# Out:
# [1] "Content of file:"
#   ID Last.Name First.Name City        State      Gender Student.Status Major
# 1 1  DOE01     JANE01     Los Angeles California Female Graduate       Politics
# 2 2  DOE02     JANE02     Sedona      Arizona    Female Undergraduate  Math
# 3 3  DOE01     JOE01      Elmira      New York   Male   Graduate       Math
# 4 4  DOE02     JOE02      Lackawana   New York   Male   Graduate       Econ
# 5 5  DOE03     JOE03      Defiance    Ohio       Male   Graduate       Econ
# 6 6  DOE04     JOE04      Tel Aviv    Israel     Male   Graduate       Econ
#   Country Age ⋯ NA..12 NA..13 NA..14 NA..15 NA..16 NA..17 NA..18 NA..19 NA..20
# 1 US      30  ⋯ NA     NA     NA     NA     NA     NA     NA     NA     NA
# 2 US      19  ⋯ NA     NA     NA     NA     NA     NA     NA     NA     NA
# 3 US      26  ⋯ NA     NA     NA     NA     NA     NA     NA     NA     NA
# 4 US      33  ⋯ NA     NA     NA     NA     NA     NA     NA     NA     NA
# ...

# %%
df <- df[colSums(!is.na(df)) > 0]
head(df)
# Out:
#   ID Last.Name First.Name City        State      Gender Student.Status Major
# 1 1  DOE01     JANE01     Los Angeles California Female Graduate       Politics
# 2 2  DOE02     JANE02     Sedona      Arizona    Female Undergraduate  Math
# 3 3  DOE01     JOE01      Elmira      New York   Male   Graduate       Math
# 4 4  DOE02     JOE02      Lackawana   New York   Male   Graduate       Econ
# 5 5  DOE03     JOE03      Defiance    Ohio       Male   Graduate       Econ
# 6 6  DOE04     JOE04      Tel Aviv    Israel     Male   Graduate       Econ
#   Country Age SAT  Average.score..grade. Height..in.
# 1 US      30  2263 67.00000              61
# 2 US      19  2006 63.00000              64
# 3 US      26  2221 78.11328              73
# 4 US      33  1716 77.80859              68
# 5 US      37  1701 65.00000              71
# 6 Israel  25  1786 69.00000              67
#   Newspaper.readership..times.wk.
# 1 5
# 2 7
# 3 6
# 4 3
# 5 6
# 6 5

# %%
df <- na.omit(df)

# %%
df
# Out:
#    ID Last.Name First.Name City           State          Gender Student.Status
# 1   1 DOE01     JANE01     Los Angeles    California     Female Graduate
# 2   2 DOE02     JANE02     Sedona         Arizona        Female Undergraduate
# 3   3 DOE01     JOE01      Elmira         New York       Male   Graduate
# 4   4 DOE02     JOE02      Lackawana      New York       Male   Graduate
# 5   5 DOE03     JOE03      Defiance       Ohio           Male   Graduate
# 6   6 DOE04     JOE04      Tel Aviv       Israel         Male   Graduate
# 7   7 DOE05     JOE05      Cimax          North Carolina Male   Graduate
# 8   8 DOE03     JANE03     Liberal        Kansas         Female Undergraduate
# 9   9 DOE04     JANE04     Montreal       Canada         Female Undergraduate
# 10 10 DOE05     JANE05     New York       New York       Female Graduate
# 11 11 DOE06     JOE06      Hot Coffe      Mississippi    Male   Undergraduate
# ...

# %%
df <- df[, 4:14]
head(df)

str(df)
# Out:
#   City        State      Gender Student.Status Major    Country Age SAT
# 1 Los Angeles California Female Graduate       Politics US      30  2263
# 2 Sedona      Arizona    Female Undergraduate  Math     US      19  2006
# 3 Elmira      New York   Male   Graduate       Math     US      26  2221
# 4 Lackawana   New York   Male   Graduate       Econ     US      33  1716
# 5 Defiance    Ohio       Male   Graduate       Econ     US      37  1701
# 6 Tel Aviv    Israel     Male   Graduate       Econ     Israel  25  1786
#   Average.score..grade. Height..in. Newspaper.readership..times.wk.
# 1 67.00000              61          5
# 2 63.00000              64          7
# 3 78.11328              73          6
# 4 77.80859              68          3
# 5 65.00000              71          6
# 6 69.00000              67          5
# 'data.frame':	30 obs. of  11 variables:
#  $ City                           : chr  "Los Angeles" "Sedona" "Elmira" "Lackawana" ...
# ...

# %%
summary(df)

major <- table(df$Major)
colors1 <- c("red", "yellow", "green")
gender <- table(df$Gender)
colors2 <- c("blue", "pink")
status <- table(df$Student.Status)
colors3 <- c("violet", "cyan")
# Out:
#      City              State              Gender          Student.Status
#  Length:30          Length:30          Length:30          Length:30
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#
#
#
#     Major             Country               Age            SAT
#  Length:30          Length:30          Min.   :18.0   Min.   :1338
#  Class :character   Class :character   1st Qu.:19.0   1st Qu.:1658
#  Mode  :character   Mode  :character   Median :23.0   Median :1817
#                                        Mean   :25.2   Mean   :1849
#                                        3rd Qu.:30.0   3rd Qu.:2032
#                                        Max.   :39.0   Max.   :2309
#  Average.score..grade.  Height..in.    Newspaper.readership..times.wk.
#  Min.   :63.00         Min.   :59.00   Min.   :3.000
#  1st Qu.:72.00         1st Qu.:63.00   1st Qu.:4.000
# ...

# %%
pie(major, col=colors1, main="Number of Students per Major")
# Out:
# Plot with title “Number of Students per Major”

# %%
pie(gender, col=colors2, main="Male vs Female")
# Out:
# Plot with title “Male vs Female”

# %%
pie(status, col=colors3, main="Graduate vs Undergraduate")
# Out:
# Plot with title “Graduate vs Undergraduate”

# %%
sapply(df[7:11], var)

sapply(df[7:11], sd)
# Out:
#                             Age                             SAT
#                       47.200000                    75686.713793
#           Average.score..grade.                     Height..in.
#                      102.130104                       21.702299
# Newspaper.readership..times.wk.
#                        1.636782
#                             Age                             SAT
#                        6.870226                      275.112184
#           Average.score..grade.                     Height..in.
#                       10.105944                        4.658573
# Newspaper.readership..times.wk.
#                        1.279368

# %%
install.packages("e1071")
library("e1071")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘proxy’

# %%
skew <- apply(df[,7:11], 2, skewness)
skew
# Out:
#                             Age                             SAT
#                      0.50270966                      0.14044713
#           Average.score..grade.                     Height..in.
#                     -0.10137424                      0.15508544
# Newspaper.readership..times.wk.
#                     -0.04683474

# %%
kur <- apply(df[,7:11], 2, kurtosis)
kur
# Out:
#                             Age                             SAT
#                       -1.202428                       -1.042817
#           Average.score..grade.                     Height..in.
#                       -1.156974                       -1.215848
# Newspaper.readership..times.wk.
#                       -1.141655

# %%
par(mfrow=c(2,2))

hist(df$Age, main = "Ages",
xlab = "Ages",
xlim = c(min(df$Age)-5, max(df$Age)+5),
col = "orange",
breaks = 10,
border = "blue",
las = 1,
freq=FALSE
)
lines(density(df$Age))
# Out:
# Plot with title “Ages”

# %%
hist(df$SAT, main = "SAT",
xlab = "SAT",
xlim = c(min(df$SAT)-10, max(df$SAT)+10),
col = "orange",
breaks = 10,
border = "blue",
las = 1,
freq=FALSE
)
lines(density(df$SAT))
# Out:
# Plot with title “SAT”

# %%
hist(df$Average.score..grade., main = "Avg Score Grade",
xlab = "Avg score",
xlim = c(min(df$Average.score..grade.)-10, max(df$Average.score..grade.)+10),
col = "orange",
breaks = 10,
border = "blue",
las = 1,
freq=FALSE
)
lines(density(df$Average.score..grade.))
# Out:
# Plot with title “Avg Score Grade”

# %%
hist(df$Height..in., main = "Height in",
xlab = "Height in",
xlim = c(min(df$Average.score..grade.)-10, max(df$Average.score..grade.)+10),
col = "orange",
breaks = 10,
border = "blue",
las = 1,
freq=FALSE
)
lines(density(df$Height..in.))
# Out:
# Plot with title “Height in”

# %% [markdown]
# **Bài toán 2**: Xem xét một bộ dữ liệu 40 mẫu khác cho một nhãn hiệu pin
# khác (Battery 2). Các quan sát được liệt kê trong tập tin
# life_batteries_2.txt.

# %%
#https://drive.google.com/file/d/13Ney4PRRmEvF3SSj9NtYQmAqa6uy-5ON/view?usp=sharing
system('gdown --id 13Ney4PRRmEvF3SSj9NtYQmAqa6uy-5ON')

# %%
df2 <- read.csv("life_batteries_2.txt", sep = "\t", header = F)
print("Content of file:")
print(df2)
# Out:
# [1] "Content of file:"
#     V1  V2  V3  V4
# 1  134 130 140 151
# 2  143 134 136 144
# 3  150 135 160 141
# 4  143 140 138 141
# 5  148 146 140 146
# 6  151 138 151 139
# 7  151 128 146 147
# 8  152 142 144 134
# 9  142 146 142 136
# 10 122 134 145 147

# %%
data2 <- c(df2$V1, df2$V2, df2$V3, df2$V4)
data2
# Out:
#  [1] 134 143 150 143 148 151 151 152 142 122 130 134 135 140 146 138 128 142 146
# [20] 134 140 136 160 138 140 151 146 144 142 145 151 144 141 141 146 139 147 134
# [39] 136 147

# %%
par(mfrow=c(1,2))
hist(data2, main = "Life Batteries 2", xlab = "Hours",
xlim = c(110, max(data2)+10), ylim = c(0, 20), col = "orange",
border = "blue", breaks = 5)
# Create the histogram.
hist(data2, main = "Life batteries",
xlab = "Hours",
xlim = c(110, max(data2)+10),
col = "orange",
breaks = 10,
border = "blue",
# so lieu tren y theo hang ngang
las = 1,
freq=FALSE
)
lines(density(data2))
# Out:
# Plot with title “Life batteries”

# %% [markdown]
# **Nhận xét**
#
# Biểu đồ trên cho thấy rằng có nhiều dữ liệu hơn cho Battery 2 trong khoảng 140 so với
# Battery 1 trong khoảng 130. Ngoài ra, mức độ biến thiên của Battery 2 ít hơn so với Battery 1.
# Dựa trên các kết quả này, có thể kết luận rằng Battery 2 là một nhãn hiệu tốt hơn (trung bình
# cao hơn và biến thiên thấp hơn). Tuy nhiên, tính hợp lệ của kết luận này còn phụ thuộc vào
# cách thu thập dữ liệu.

# %%
summary(data2)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   122.0   137.5   142.0   141.9   146.2   160.0

# %%
var(data2)
# Out:
# [1] 55.19936

# %%
sd(data2)
# Out:
# [1] 7.429627

# %%
install.packages("moments")
library("moments")
skewness(data2)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
#
# Attaching package: ‘moments’
#
#
# The following objects are masked from ‘package:e1071’:
#
#     kurtosis, moment, skewness
# [1] -0.2510339

# %%
kurtosis(data2)
# Out:
# [1] 3.356703

# %% [markdown]
# Phân phối cao hơn phân phối chuẩn
#
# Nhận xét:
# Những kết quả này cho thấy rằng Pin 2 có tuổi thọ trung bình cao hơn so với Pin 1 và Pin 2
# có phương sai nhỏ hơn.
# Pin 1 có skewness > 0: phân phối lệch phải
# Pin 2 có skewness < 0: phân phối lệch trái
# Pin 1 có kurtosis < 0: phân bố này thấp hơn phân bố chuẩn
# Pin 2 có kurtosis > 0: phân bố này cao hơn phân bố chuẩn
