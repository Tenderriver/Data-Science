# %% [markdown]
# ## Chapter 7 - Exercise 3:  Visualization with Seaborn - Diamond

# %% [markdown]
# _Nghịch lý Simpson hay hiệu ứng Yule–Simpson, là một nghịch lý trong xác suất và thống kê, trong đó một xu hướng xuất hiện trong dữ liệu sẽ bị đảo ngược khi được phân tích dưới góc nhìn khác._

# %% [markdown]
# #### Cho file dữ liệu diamonds.csv. Hãy thực hiện các yêu cầu sau, để phát hiện nghịch lý Simpson khi phân tích giá kim cương bằng các công cụ trực quan hóa dữ liệu:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style("darkgrid")

# %%
# Câu 1: Đọc dữ liệu diamonds.csv, đưa vào biến diamonds
diamonds=pd.read_csv('diamonds.csv')
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div>
# <style scoped="">
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>carat</th>
#       <th>cut</th>
#       <th>color</th>
#       <th>clarity</th>
#       <th>depth</th>
#       <th>table</th>
#       <th>price</th>
#       <th>x</th>
#       <th>y</th>
#       <th>z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.23</td>
#       <td>Ideal</td>
#       <td>E</td>
#       <td>SI2</td>
#       <td>61.5</td>
#       <td>55.0</td>
#       <td>326</td>
#       <td>3.95</td>
#       <td>3.98</td>
#       <td>2.43</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.21</td>
#       <td>Premium</td>
#       <td>E</td>
#       <td>SI1</td>
#       <td>59.8</td>
#       <td>61.0</td>
#       <td>326</td>
#       <td>3.89</td>
#       <td>3.84</td>
#       <td>2.31</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.23</td>
#       <td>Good</td>
#       <td>E</td>
#       <td>VS1</td>
#       <td>56.9</td>
#       <td>65.0</td>
#       <td>327</td>
#       <td>4.05</td>
#       <td>4.07</td>
#       <td>2.31</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.29</td>
#       <td>Premium</td>
#       <td>I</td>
#       <td>VS2</td>
#       <td>62.4</td>
#       <td>58.0</td>
#       <td>334</td>
#       <td>4.20</td>
#       <td>4.23</td>
#       <td>2.63</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.31</td>
#       <td>Good</td>
#       <td>J</td>
#       <td>SI2</td>
#       <td>63.3</td>
#       <td>58.0</td>
#       <td>335</td>
#       <td>4.34</td>
#       <td>4.35</td>
#       <td>2.75</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# </details>

# %%
diamonds.color.unique()
# Out:
# array(['E', 'I', 'J', 'H', 'F', 'G', 'D'], dtype=object)

# %%
# Câu 2: Vẽ biểu đồ bar so sánh giá của kim cương theo color, cut và clarity
# Bạn nhận xét gì qua biểu đồ này
fig,axes=plt.subplots(1,3,figsize=(15,5))
fig.suptitle('Price Decreasing with Increasing Quality?')
sns.barplot(ax=axes[0],x=diamonds.color,y=diamonds.price)
sns.barplot(ax=axes[1],x=diamonds.cut,y=diamonds.price)
sns.barplot(ax=axes[2],x=diamonds.clarity,y=diamonds.price)
plt.show()

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div class="output_subarea output_png"><img src="data:image/png;base64,...
# "></div>
#
# </details>

# %% [markdown]
# > Có gì đó không ổn ???

# %%
# Câu 3: Bây giờ, hãy thử Phân tích chi tiết hơn thuộc tính 'carat' theo 'color' và 'clarity' qua biểu đồ catplot - bar plot
# Bạn nhận xét gì qua biểu đồ này
fig.suptitle('Price Decreasing with Increasing Quality?')
sns.catplot(data=diamonds,x='color',y='carat',kind='bar',col='clarity',col_wrap=4,linewidth=2,sharex=True)

plt.show()

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div class="output_subarea output_png"><img src="data:image/png;base64,...
# "></div>
#
# </details>

# %%
# Câu 4: Vẽ biểu đồ bar so sánh 'carat' của kim cương theo color, cut và clarity
fig,axes=plt.subplots(1,3,figsize=(15,5))
fig.suptitle('Diamond Size and Quality')
sns.barplot(ax=axes[0],x=diamonds.color,y=diamonds.carat)
sns.barplot(ax=axes[1],x=diamonds.cut,y=diamonds.carat)
sns.barplot(ax=axes[2],x=diamonds.clarity,y=diamonds.carat)
plt.show()

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div class="output_subarea output_png"><img src="data:image/png;base64,...
# "></div>
#
# </details>

# %%
# Câu 5: Hãy chia carat ra làm 5 khoảng giá trị, tạo cột diamonds['carat_category'] chứa khoảng giá trị tương ứng 
# Hướng dẫn: sử dụng hàm pd.qcut
diamonds['carat_category']=pd.qcut(diamonds.carat,5)
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       carat_category
# 0      (0.199, 0.35]
# 1      (0.199, 0.35]
# 2      (0.199, 0.35]
# 3      (0.199, 0.35]
# 4      (0.199, 0.35]
# ...              ...
# 53935    (0.53, 0.9]
# 53936    (0.53, 0.9]
# 53937    (0.53, 0.9]
# 53938    (0.53, 0.9]
# 53939    (0.53, 0.9]
#
# [53940 rows x 11 columns]

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div>
# <style scoped="">
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>carat</th>
#       <th>cut</th>
#       <th>color</th>
#       <th>clarity</th>
#       <th>depth</th>
#       <th>table</th>
#       <th>price</th>
#       <th>x</th>
#       <th>y</th>
#       <th>z</th>
#       <th>carat_category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.23</td>
#       <td>Ideal</td>
#       <td>E</td>
#       <td>SI2</td>
#       <td>61.5</td>
#       <td>55.0</td>
#       <td>326</td>
#       <td>3.95</td>
#       <td>3.98</td>
#       <td>2.43</td>
#       <td>(0.199, 0.35]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.21</td>
#       <td>Premium</td>
#       <td>E</td>
#       <td>SI1</td>
#       <td>59.8</td>
#       <td>61.0</td>
#       <td>326</td>
#       <td>3.89</td>
#       <td>3.84</td>
#       <td>2.31</td>
#       <td>(0.199, 0.35]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.23</td>
#       <td>Good</td>
#       <td>E</td>
#       <td>VS1</td>
#       <td>56.9</td>
#       <td>65.0</td>
#       <td>327</td>
#       <td>4.05</td>
#       <td>4.07</td>
#       <td>2.31</td>
#       <td>(0.199, 0.35]</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.29</td>
#       <td>Premium</td>
#       <td>I</td>
#       <td>VS2</td>
#       <td>62.4</td>
#       <td>58.0</td>
#       <td>334</td>
#       <td>4.20</td>
#       <td>4.23</td>
#       <td>2.63</td>
#       <td>(0.199, 0.35]</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.31</td>
#       <td>Good</td>
#       <td>J</td>
#       <td>SI2</td>
#       <td>63.3</td>
#       <td>58.0</td>
#       <td>335</td>
#       <td>4.34</td>
#       <td>4.35</td>
#       <td>2.75</td>
#       <td>(0.199, 0.35]</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# </details>

# %%
# Câu 6: Phân tích chi tiết hơn thuộc tính 'price' theo  'clarity','carat_category','color' qua biểu đồ catplot - point plot
fig.suptitle('Price Decreasing with Increasing Quality?')
sns.catplot(data=diamonds,x='clarity',y='price',kind='point',col='color',hue='carat_category',col_wrap=4,linewidth=2,sharex=True)

plt.show()

# %% [markdown]
# <details>
#   <summary>Nhấn vào đây để xem kết quả!</summary>
#   <div class="output_subarea output_png"><img src="data:image/png;base64,...
# "></div>
#
# </details>

# %%
# Câu 7: Kết luận
